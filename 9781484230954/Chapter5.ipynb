# %% [markdown]
# # Listing 5-1. Computation of Pi through Monte Carlo Sampling

# %%
import numpy as np
number_sample = 100000
inner_area,outer_area = 0,0

for i in range(number_sample):
    x = np.random.uniform(0,1)
    y = np.random.uniform(0,1)
    if (x**2 + y**2) < 1 :
        inner_area += 1
    outer_area += 1

print("The computed value of Pi:",4*(inner_area/float(outer_area)))
# Out:
# ('The computed value of Pi:', 3.14516)

# %% [markdown]
# # Listing 5-2. Bivariate Gaussian distribution Sampling through Metropolis Algorithm

# %%
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
#Now lets generate this with one of the Markov Chain Monte Carlo method called Metropolis Hastings algorithm
# Our assumed transition probabilities would follow normal distribution X2 ~ N(X1,Covariance= [[0.2 , 0],[0,0.2]])
import time
start_time = time.time()

# Set up constants and initial variable conditions
num_samples=100000
prob_density = 0

## Plan is to sample from a Bivariate Guassian Distribution with mean (0,0) and covariance of
## 0.7 between the two variables

mean = np.array([0,0])
cov = np.array([[1,0.7],[0.7,1]])
cov1 = np.matrix(cov)
mean1 = np.matrix(mean)
x_list,y_list = [],[]
accepted_samples_count = 0

## Normalizer of the Probility distibution
## This is not actually required since we are taking ratio of probabilities for inference

normalizer = np.sqrt( ((2*np.pi)**2)*np.linalg.det(cov))
## Start with initial Point (0,0)
x_initial, y_initial = 0,0
x1,y1 = x_initial, y_initial
for i in xrange(num_samples):
    
## Set up the Conditional Probability distribution taking the existing point
## as the mean and a small variance = 0.2 so that points near the existing point
## have a high chance of getting sampled.

    mean_trans = np.array([x1,y1])
    cov_trans = np.array([[0.2,0],[0,0.2]])
    x2,y2 = np.random.multivariate_normal(mean_trans,cov_trans).T
    X = np.array([x2,y2])
    X2 = np.matrix(X)
    X1 = np.matrix(mean_trans)

    ## Compute the probability density of te existing point and the new sampled
    ## point

    mahalnobis_dist2 = (X2 - mean1)*np.linalg.inv(cov)*(X2 - mean1).T
    prob_density2 = (1/float(normalizer))*np.exp(-0.5*mahalnobis_dist2)
    mahalnobis_dist1 = (X1 - mean1)*np.linalg.inv(cov)*(X1 - mean1).T
    prob_density1 = (1/float(normalizer))*np.exp(-0.5*mahalnobis_dist1)

    ## This is the heart of the algorithm. Comparing the ratio of Probability density of the new
    ## point and the existing point(acceptance_ratio) and selecting the new point if it is have more probability
    ## density. If it has less probability it is randomly selected with the probability of getting
    ## selected being proportional to the ratio of the acceptance ratio
    acceptance_ratio = prob_density2[0,0] / float(prob_density1[0,0])

    if (acceptance_ratio >= 1) | ((acceptance_ratio < 1) and (acceptance_ratio >= np.random.uniform(0,1)) ) :
        x_list.append(x2)
        y_list.append(y2)
        x1 = x2
        y1 = y2
        accepted_samples_count += 1

end_time = time.time()

print ('Time taken to sample ' + str(accepted_samples_count) + ' points ==> ' + str(end_time - start_time) + ' seconds' )
print 'Acceptance ratio ===> ' , accepted_samples_count/float(100000)
print "Mean of the Sampled Points"
print np.mean(x_list),np.mean(y_list)
print "Covariance matrix of the Sampled Points"
print np.cov(x_list,y_list) 
## Time to display the samples generated
plt.xlabel('X')
plt.ylabel('Y')
print "Scatter plot for the Sampled Points"
plt.scatter(x_list,y_list,color='black')
# Out:
# Time taken to sample 71405 points ==> 13.1268599033 seconds
# Acceptance ratio ===>  0.71405
# Mean of the Sampled Points
# -0.0263982892077 -0.0326721053731
# Covariance matrix of the Sampled Points
# [[ 0.97677798  0.697723  ]
#  [ 0.697723    0.9946079 ]]
# Scatter plot for the Sampled Points

# %% [markdown]
# # Listing 5-3a. Restricted Boltzmann Machine Implementation with MNIST dataset

# %%
##Import the Required libraries 
import numpy as np
import pandas as pd
import tensorflow as tf
import matplotlib.pyplot as plt
# %matplotlib inline

## Read the MNIST files
from tensorflow.examples.tutorials.mnist import input_data
mnist = input_data.read_data_sets("MNIST_data", one_hot=True)

## Set up the parameters for training 


n_visible      = 784
n_hidden    = 500
display_step = 1
num_epochs = 200 
batch_size = 256 
lr         = tf.constant(0.001, tf.float32)

## Define the tensorflow variables for weights and biases as well as placeholder for input
x  = tf.placeholder(tf.float32, [None, n_visible], name="x") 
W  = tf.Variable(tf.random_normal([n_visible, n_hidden], 0.01), name="W") 
b_h = tf.Variable(tf.zeros([1, n_hidden],  tf.float32, name="b_h")) 
b_v = tf.Variable(tf.zeros([1, n_visible],  tf.float32, name="b_v")) 

## Converts the probability into discrete binary states i.e. 0 and 1 
def sample(probs):
    return tf.floor(probs + tf.random_uniform(tf.shape(probs), 0, 1))
          
  
## Gibbs sampling step
def gibbs_step(x_k):
        h_k = sample(tf.sigmoid(tf.matmul(x_k, W) + b_h)) 
        x_k = sample(tf.sigmoid(tf.matmul(h_k, tf.transpose(W)) + b_v))
        return x_k
## Run multiple gives Sampling step starting from an initital point     
def gibbs_sample(k,x_k):
    for i in range(k):
        x_out = gibbs_step(x_k) 
# Returns the gibbs sample after k iterations
    return x_out

# Constrastive Divergence algorithm
# 1. Through Gibbs sampling locate a new visible state x_sample based on the current visible state x    
# 2. Based on the new x sample a new h as h_sample    
x_s = gibbs_sample(2,x) 
h_s = sample(tf.sigmoid(tf.matmul(x_s, W) + b_h)) 

# Sample hidden states based given visible states
h = sample(tf.sigmoid(tf.matmul(x, W) + b_h)) 
# Sample visible states based given hidden states
x_ = sample(tf.sigmoid(tf.matmul(h, tf.transpose(W)) + b_v))

# The weight updated based on gradient descent 
size_batch = tf.cast(tf.shape(x)[0], tf.float32)
W_add  = tf.multiply(lr/size_batch, tf.subtract(tf.matmul(tf.transpose(x), h), tf.matmul(tf.transpose(x_s), h_s)))
bv_add = tf.multiply(lr/size_batch, tf.reduce_sum(tf.subtract(x, x_s), 0, True))
bh_add = tf.multiply(lr/size_batch, tf.reduce_sum(tf.subtract(h, h_s), 0, True))
updt = [W.assign_add(W_add), b_v.assign_add(bv_add), b_h.assign_add(bh_add)]

# TensorFlow graph execution

with tf.Session() as sess:
    # Initialize the variables of the Model
    init = tf.global_variables_initializer()
    sess.run(init)
    
    total_batch = int(mnist.train.num_examples/batch_size)
    # Start the training 
    for epoch in range(num_epochs):
        # Loop over all batches
        for i in range(total_batch):
            batch_xs, batch_ys = mnist.train.next_batch(batch_size)
            # Run the weight update 
            batch_xs = (batch_xs > 0)*1
            _ = sess.run([updt], feed_dict={x:batch_xs})
            
        # Display the running step 
        if epoch % display_step == 0:
            print("Epoch:", '%04d' % (epoch+1))
                  
    print("RBM training Completed !")
    
    
    out = sess.run(h,feed_dict={x:(mnist.test.images[:20]> 0)*1})
    label = mnist.test.labels[:20]
    
    plt.figure(1)
    for k in range(20):
        plt.subplot(4, 5, k+1)
        image = (mnist.test.images[k]> 0)*1
        image = np.reshape(image,(28,28))
        plt.imshow(image,cmap='gray')
       
    plt.figure(2)
    
    for k in range(20):
        plt.subplot(4, 5, k+1)
        image = sess.run(x_,feed_dict={h:np.reshape(out[k],(-1,n_hidden))})
        image = np.reshape(image,(28,28))
        plt.imshow(image,cmap='gray')
        print(np.argmax(label[k]))
        
    W_out = sess.run(W)
    
    
    sess.close()
# Out:
# Extracting MNIST_data/train-images-idx3-ubyte.gz
# Extracting MNIST_data/train-labels-idx1-ubyte.gz
# Extracting MNIST_data/t10k-images-idx3-ubyte.gz
# Extracting MNIST_data/t10k-labels-idx1-ubyte.gz
# ('Epoch:', '0001')
# ('Epoch:', '0002')
# ('Epoch:', '0003')
# ('Epoch:', '0004')
# ('Epoch:', '0005')
# ('Epoch:', '0006')
# ('Epoch:', '0007')
# ('Epoch:', '0008')
# ('Epoch:', '0009')
# ('Epoch:', '0010')
# ('Epoch:', '0011')
# ('Epoch:', '0012')
# ('Epoch:', '0013')
# ('Epoch:', '0014')
# ('Epoch:', '0015')
# ('Epoch:', '0016')
# ('Epoch:', '0017')
# ('Epoch:', '0018')
# ('Epoch:', '0019')
# ('Epoch:', '0020')
# ('Epoch:', '0021')
# ('Epoch:', '0022')
# ('Epoch:', '0023')
# ('Epoch:', '0024')
# ('Epoch:', '0025')
# ('Epoch:', '0026')
# ('Epoch:', '0027')
# ('Epoch:', '0028')
# ('Epoch:', '0029')
# ('Epoch:', '0030')
# ('Epoch:', '0031')
# ('Epoch:', '0032')
# ('Epoch:', '0033')
# ('Epoch:', '0034')
# ('Epoch:', '0035')
# ('Epoch:', '0036')
# ('Epoch:', '0037')
# ('Epoch:', '0038')
# ('Epoch:', '0039')
# ('Epoch:', '0040')
# ('Epoch:', '0041')
# ('Epoch:', '0042')
# ('Epoch:', '0043')
# ('Epoch:', '0044')
# ('Epoch:', '0045')
# ('Epoch:', '0046')
# ('Epoch:', '0047')
# ('Epoch:', '0048')
# ('Epoch:', '0049')
# ('Epoch:', '0050')
# ('Epoch:', '0051')
# ('Epoch:', '0052')
# ('Epoch:', '0053')
# ('Epoch:', '0054')
# ('Epoch:', '0055')
# ('Epoch:', '0056')
# ('Epoch:', '0057')
# ('Epoch:', '0058')
# ('Epoch:', '0059')
# ('Epoch:', '0060')
# ('Epoch:', '0061')
# ('Epoch:', '0062')
# ('Epoch:', '0063')
# ('Epoch:', '0064')
# ('Epoch:', '0065')
# ('Epoch:', '0066')
# ('Epoch:', '0067')
# ('Epoch:', '0068')
# ('Epoch:', '0069')
# ('Epoch:', '0070')
# ('Epoch:', '0071')
# ('Epoch:', '0072')
# ('Epoch:', '0073')
# ('Epoch:', '0074')
# ('Epoch:', '0075')
# ('Epoch:', '0076')
# ('Epoch:', '0077')
# ('Epoch:', '0078')
# ('Epoch:', '0079')
# ('Epoch:', '0080')
# ('Epoch:', '0081')
# ('Epoch:', '0082')
# ('Epoch:', '0083')
# ('Epoch:', '0084')
# ('Epoch:', '0085')
# ('Epoch:', '0086')
# ('Epoch:', '0087')
# ('Epoch:', '0088')
# ('Epoch:', '0089')
# ('Epoch:', '0090')
# ('Epoch:', '0091')
# ('Epoch:', '0092')
# ('Epoch:', '0093')
# ('Epoch:', '0094')
# ('Epoch:', '0095')
# ('Epoch:', '0096')
# ('Epoch:', '0097')
# ('Epoch:', '0098')
# ('Epoch:', '0099')
# ('Epoch:', '0100')
# ('Epoch:', '0101')
# ('Epoch:', '0102')
# ('Epoch:', '0103')
# ('Epoch:', '0104')
# ('Epoch:', '0105')
# ('Epoch:', '0106')
# ('Epoch:', '0107')
# ('Epoch:', '0108')
# ('Epoch:', '0109')
# ('Epoch:', '0110')
# ('Epoch:', '0111')
# ('Epoch:', '0112')
# ('Epoch:', '0113')
# ('Epoch:', '0114')
# ('Epoch:', '0115')
# ('Epoch:', '0116')
# ('Epoch:', '0117')
# ('Epoch:', '0118')
# ('Epoch:', '0119')
# ('Epoch:', '0120')
# ('Epoch:', '0121')
# ('Epoch:', '0122')
# ('Epoch:', '0123')
# ('Epoch:', '0124')
# ('Epoch:', '0125')
# ('Epoch:', '0126')
# ('Epoch:', '0127')
# ('Epoch:', '0128')
# ('Epoch:', '0129')
# ('Epoch:', '0130')
# ('Epoch:', '0131')
# ('Epoch:', '0132')
# ('Epoch:', '0133')
# ('Epoch:', '0134')
# ('Epoch:', '0135')
# ('Epoch:', '0136')
# ('Epoch:', '0137')
# ('Epoch:', '0138')
# ('Epoch:', '0139')
# ('Epoch:', '0140')
# ('Epoch:', '0141')
# ('Epoch:', '0142')
# ('Epoch:', '0143')
# ('Epoch:', '0144')
# ('Epoch:', '0145')
# ('Epoch:', '0146')
# ('Epoch:', '0147')
# ('Epoch:', '0148')
# ('Epoch:', '0149')
# ('Epoch:', '0150')
# ('Epoch:', '0151')
# ('Epoch:', '0152')
# ('Epoch:', '0153')
# ('Epoch:', '0154')
# ('Epoch:', '0155')
# ('Epoch:', '0156')
# ('Epoch:', '0157')
# ('Epoch:', '0158')
# ('Epoch:', '0159')
# ('Epoch:', '0160')
# ('Epoch:', '0161')
# ('Epoch:', '0162')
# ('Epoch:', '0163')
# ('Epoch:', '0164')
# ('Epoch:', '0165')
# ('Epoch:', '0166')
# ('Epoch:', '0167')
# ('Epoch:', '0168')
# ('Epoch:', '0169')
# ('Epoch:', '0170')
# ('Epoch:', '0171')
# ('Epoch:', '0172')
# ('Epoch:', '0173')
# ('Epoch:', '0174')
# ('Epoch:', '0175')
# ('Epoch:', '0176')
# ('Epoch:', '0177')
# ('Epoch:', '0178')
# ('Epoch:', '0179')
# ('Epoch:', '0180')
# ('Epoch:', '0181')
# ('Epoch:', '0182')
# ('Epoch:', '0183')
# ('Epoch:', '0184')
# ('Epoch:', '0185')
# ('Epoch:', '0186')
# ('Epoch:', '0187')
# ('Epoch:', '0188')
# ('Epoch:', '0189')
# ('Epoch:', '0190')
# ('Epoch:', '0191')
# ('Epoch:', '0192')
# ('Epoch:', '0193')
# ('Epoch:', '0194')
# ('Epoch:', '0195')
# ('Epoch:', '0196')
# ('Epoch:', '0197')
# ('Epoch:', '0198')
# ('Epoch:', '0199')
# ('Epoch:', '0200')
# RBM training Completed !
# 7
# 2
# 1
# 0
# 4
# 1
# 4
# 9
# 5
# 9
# 0
# 6
# 9
# 0
# 1
# 5
# 9
# 7
# 3
# 4

# %% [markdown]
# # Listing 5-3b. Basic Implementation of Deep Belief Network

# %%
##Import the Required libraries 
import numpy as np
import pandas as pd
import tensorflow as tf
import matplotlib.pyplot as plt
# %matplotlib inline

## Read the MNIST files
from tensorflow.examples.tutorials.mnist import input_data
mnist = input_data.read_data_sets("MNIST_data", one_hot=True)

## Set up the parameters for training 


n_visible      = 784
n_hidden    = 500
display_step = 1
num_epochs = 200 
batch_size = 256 
lr         = tf.constant(0.001, tf.float32)
learning_rate_train = tf.constant(0.01, tf.float32)
n_classes = 10
training_iters = 200
## Define the tensorflow variables for weights and biases as well as placeholder for input
x  = tf.placeholder(tf.float32, [None, n_visible], name="x") 
y  = tf.placeholder(tf.float32, [None,10], name="y") 

W  = tf.Variable(tf.random_normal([n_visible, n_hidden], 0.01), name="W") 
b_h = tf.Variable(tf.zeros([1, n_hidden],  tf.float32, name="b_h")) 
b_v = tf.Variable(tf.zeros([1, n_visible],  tf.float32, name="b_v")) 
W_f = tf.Variable(tf.random_normal([n_hidden,n_classes], 0.01), name="W_f") 
b_f = tf.Variable(tf.zeros([1, n_classes],  tf.float32, name="b_f")) 
## Converts the probability into discrete binary states i.e. 0 and 1 
def sample(probs):
    return tf.floor(probs + tf.random_uniform(tf.shape(probs), 0, 1))
          
  
## Gibbs sampling step
def gibbs_step(x_k):
        h_k = sample(tf.sigmoid(tf.matmul(x_k, W) + b_h)) 
        x_k = sample(tf.sigmoid(tf.matmul(h_k, tf.transpose(W)) + b_v))
        return x_k
## Run multiple gives Sampling step starting from an initital point     
def gibbs_sample(k,x_k):
    for i in range(k):
        x_out = gibbs_step(x_k) 
# Returns the gibbs sample after k iterations
    return x_out

# Constrastive Divergence algorithm
# 1. Through Gibbs sampling locate a new visible state x_sample based on the current visible state x    
# 2. Based on the new x sample a new h as h_sample    
x_s = gibbs_sample(2,x) 
h_s = sample(tf.sigmoid(tf.matmul(x_s, W) + b_h)) 

# Sample hidden states based given visible states
h = sample(tf.sigmoid(tf.matmul(x, W) + b_h)) 
# Sample visible states based given hidden states
x_ = sample(tf.sigmoid(tf.matmul(h, tf.transpose(W)) + b_v))

# The weight updated based on gradient descent 
size_batch = tf.cast(tf.shape(x)[0], tf.float32)
W_add  = tf.multiply(lr/size_batch, tf.subtract(tf.matmul(tf.transpose(x), h), tf.matmul(tf.transpose(x_s), h_s)))
bv_add = tf.multiply(lr/size_batch, tf.reduce_sum(tf.subtract(x, x_s), 0, True))
bh_add = tf.multiply(lr/size_batch, tf.reduce_sum(tf.subtract(h, h_s), 0, True))
updt = [W.assign_add(W_add), b_v.assign_add(bv_add), b_h.assign_add(bh_add)]
#--------------------------------------------------------------

## Ops for the Classification Network

#-------------------------------------------------------------- 
h_out = tf.sigmoid(tf.matmul(x, W) + b_h)
logits = tf.matmul(h_out,W_f) + b_f
prob = tf.nn.softmax(logits)
cost = tf.reduce_mean(tf.nn.softmax_cross_entropy_with_logits(logits=logits, labels=y))
optimizer = tf.train.AdamOptimizer(learning_rate=learning_rate_train).minimize(cost)
correct_pred = tf.equal(tf.argmax(logits,1), tf.argmax(y, 1))
accuracy = tf.reduce_mean(tf.cast(correct_pred, tf.float32))
#--------------------------------------------------------------                   
# TensorFlow graph execution of Unsupervised Pre-training with RBM
#--------------------------------------------------------------
with tf.Session() as sess:
    # Initialize the variables of the Model
    init = tf.global_variables_initializer()
    sess.run(init)
    
    total_batch = int(mnist.train.num_examples/batch_size)
    # Start the training 
    for epoch in range(num_epochs):
        # Loop over all batches
        for i in range(total_batch):
            batch_xs, batch_ys = mnist.train.next_batch(batch_size)
            # Run the weight update 
            batch_xs = (batch_xs > 0)*1
            _ = sess.run([updt], feed_dict={x:batch_xs})
            
        # Display the running step 
        if epoch % display_step == 0:
            print("Epoch:", '%04d' % (epoch+1))
                  
    print("RBM training Completed !")
    
    
    out = sess.run(h,feed_dict={x:(mnist.test.images[:20]> 0)*1})
    label = mnist.test.labels[:20]
    
    plt.figure(1)
    for k in range(20):
        plt.subplot(4, 5, k+1)
        image = (mnist.test.images[k]> 0)*1
        image = np.reshape(image,(28,28))
        plt.imshow(image,cmap='gray')
       
    plt.figure(2)
    
    for k in range(20):
        plt.subplot(4, 5, k+1)
        image = sess.run(x_,feed_dict={h:np.reshape(out[k],(-1,n_hidden))})
        image = np.reshape(image,(28,28))
        plt.imshow(image,cmap='gray')
        print(np.argmax(label[k]))
#-----------------------------------------
## Invoke the classification now
#-----------------------------------------
    
    for i in xrange(training_iters):
        batch_x, batch_y = mnist.train.next_batch(batch_size)
        # Run optimization op (backprop)
        sess.run(optimizer, feed_dict={x: batch_x, y: batch_y})
        if i % 10 == 0:
            # Calculate batch loss and accuracy
            loss, acc = sess.run([cost, accuracy], feed_dict={x: batch_x,
                                                              y: batch_y})
            print "Iter " + str(i) + ", Minibatch Loss= " + \
                  "{:.6f}".format(loss) + ", Training Accuracy= " + \
                  "{:.5f}".format(acc)
        
    print "Optimization Finished!"

    # Calculate accuracy for 256 mnist test images
    print "Testing Accuracy:", \
        sess.run(accuracy, feed_dict={x: mnist.test.images[:256],
                                      y: mnist.test.labels[:256]})

    sess.close()
# Out:
# Extracting MNIST_data/train-images-idx3-ubyte.gz
# Extracting MNIST_data/train-labels-idx1-ubyte.gz
# Extracting MNIST_data/t10k-images-idx3-ubyte.gz
# Extracting MNIST_data/t10k-labels-idx1-ubyte.gz
# ('Epoch:', '0001')
# ('Epoch:', '0002')
# ('Epoch:', '0003')
# ('Epoch:', '0004')
# ('Epoch:', '0005')
# ('Epoch:', '0006')
# ('Epoch:', '0007')
# ('Epoch:', '0008')
# ('Epoch:', '0009')
# ('Epoch:', '0010')
# ('Epoch:', '0011')
# ('Epoch:', '0012')
# ('Epoch:', '0013')
# ('Epoch:', '0014')
# ('Epoch:', '0015')
# ('Epoch:', '0016')
# ('Epoch:', '0017')
# ('Epoch:', '0018')
# ('Epoch:', '0019')
# ('Epoch:', '0020')
# ('Epoch:', '0021')
# ('Epoch:', '0022')
# ('Epoch:', '0023')
# ('Epoch:', '0024')
# ('Epoch:', '0025')
# ('Epoch:', '0026')
# ('Epoch:', '0027')
# ('Epoch:', '0028')
# ('Epoch:', '0029')
# ('Epoch:', '0030')
# ('Epoch:', '0031')
# ('Epoch:', '0032')
# ('Epoch:', '0033')
# ('Epoch:', '0034')
# ('Epoch:', '0035')
# ('Epoch:', '0036')
# ('Epoch:', '0037')
# ('Epoch:', '0038')
# ('Epoch:', '0039')
# ('Epoch:', '0040')
# ('Epoch:', '0041')
# ('Epoch:', '0042')
# ('Epoch:', '0043')
# ('Epoch:', '0044')
# ('Epoch:', '0045')
# ('Epoch:', '0046')
# ('Epoch:', '0047')
# ('Epoch:', '0048')
# ('Epoch:', '0049')
# ('Epoch:', '0050')
# ('Epoch:', '0051')
# ('Epoch:', '0052')
# ('Epoch:', '0053')
# ('Epoch:', '0054')
# ('Epoch:', '0055')
# ('Epoch:', '0056')
# ('Epoch:', '0057')
# ('Epoch:', '0058')
# ('Epoch:', '0059')
# ('Epoch:', '0060')
# ('Epoch:', '0061')
# ('Epoch:', '0062')
# ('Epoch:', '0063')
# ('Epoch:', '0064')
# ('Epoch:', '0065')
# ('Epoch:', '0066')
# ('Epoch:', '0067')
# ('Epoch:', '0068')
# ('Epoch:', '0069')
# ('Epoch:', '0070')
# ('Epoch:', '0071')
# ('Epoch:', '0072')
# ('Epoch:', '0073')
# ('Epoch:', '0074')
# ('Epoch:', '0075')
# ('Epoch:', '0076')
# ('Epoch:', '0077')
# ('Epoch:', '0078')
# ('Epoch:', '0079')
# ('Epoch:', '0080')
# ('Epoch:', '0081')
# ('Epoch:', '0082')
# ('Epoch:', '0083')
# ('Epoch:', '0084')
# ('Epoch:', '0085')
# ('Epoch:', '0086')
# ('Epoch:', '0087')
# ('Epoch:', '0088')
# ('Epoch:', '0089')
# ('Epoch:', '0090')
# ('Epoch:', '0091')
# ('Epoch:', '0092')
# ('Epoch:', '0093')
# ('Epoch:', '0094')
# ('Epoch:', '0095')
# ('Epoch:', '0096')
# ('Epoch:', '0097')
# ('Epoch:', '0098')
# ('Epoch:', '0099')
# ('Epoch:', '0100')
# ('Epoch:', '0101')
# ('Epoch:', '0102')
# ('Epoch:', '0103')
# ('Epoch:', '0104')
# ('Epoch:', '0105')
# ('Epoch:', '0106')
# ('Epoch:', '0107')
# ('Epoch:', '0108')
# ('Epoch:', '0109')
# ('Epoch:', '0110')
# ('Epoch:', '0111')
# ('Epoch:', '0112')
# ('Epoch:', '0113')
# ('Epoch:', '0114')
# ('Epoch:', '0115')
# ('Epoch:', '0116')
# ('Epoch:', '0117')
# ('Epoch:', '0118')
# ('Epoch:', '0119')
# ('Epoch:', '0120')
# ('Epoch:', '0121')
# ('Epoch:', '0122')
# ('Epoch:', '0123')
# ('Epoch:', '0124')
# ('Epoch:', '0125')
# ('Epoch:', '0126')
# ('Epoch:', '0127')
# ('Epoch:', '0128')
# ('Epoch:', '0129')
# ('Epoch:', '0130')
# ('Epoch:', '0131')
# ('Epoch:', '0132')
# ('Epoch:', '0133')
# ('Epoch:', '0134')
# ('Epoch:', '0135')
# ('Epoch:', '0136')
# ('Epoch:', '0137')
# ('Epoch:', '0138')
# ('Epoch:', '0139')
# ('Epoch:', '0140')
# ('Epoch:', '0141')
# ('Epoch:', '0142')
# ('Epoch:', '0143')
# ('Epoch:', '0144')
# ('Epoch:', '0145')
# ('Epoch:', '0146')
# ('Epoch:', '0147')
# ('Epoch:', '0148')
# ('Epoch:', '0149')
# ('Epoch:', '0150')
# ('Epoch:', '0151')
# ('Epoch:', '0152')
# ('Epoch:', '0153')
# ('Epoch:', '0154')
# ('Epoch:', '0155')
# ('Epoch:', '0156')
# ('Epoch:', '0157')
# ('Epoch:', '0158')
# ('Epoch:', '0159')
# ('Epoch:', '0160')
# ('Epoch:', '0161')
# ('Epoch:', '0162')
# ('Epoch:', '0163')
# ('Epoch:', '0164')
# ('Epoch:', '0165')
# ('Epoch:', '0166')
# ('Epoch:', '0167')
# ('Epoch:', '0168')
# ('Epoch:', '0169')
# ('Epoch:', '0170')
# ('Epoch:', '0171')
# ('Epoch:', '0172')
# ('Epoch:', '0173')
# ('Epoch:', '0174')
# ('Epoch:', '0175')
# ('Epoch:', '0176')
# ('Epoch:', '0177')
# ('Epoch:', '0178')
# ('Epoch:', '0179')
# ('Epoch:', '0180')
# ('Epoch:', '0181')
# ('Epoch:', '0182')
# ('Epoch:', '0183')
# ('Epoch:', '0184')
# ('Epoch:', '0185')
# ('Epoch:', '0186')
# ('Epoch:', '0187')
# ('Epoch:', '0188')
# ('Epoch:', '0189')
# ('Epoch:', '0190')
# ('Epoch:', '0191')
# ('Epoch:', '0192')
# ('Epoch:', '0193')
# ('Epoch:', '0194')
# ('Epoch:', '0195')
# ('Epoch:', '0196')
# ('Epoch:', '0197')
# ('Epoch:', '0198')
# ('Epoch:', '0199')
# ('Epoch:', '0200')
# RBM training Completed !
# 7
# 2
# 1
# 0
# 4
# 1
# 4
# 9
# 5
# 9
# 0
# 6
# 9
# 0
# 1
# 5
# 9
# 7
# 3
# 4
# Iter 0, Minibatch Loss= 7.632383, Training Accuracy= 0.21484
# Iter 10, Minibatch Loss= 1.504026, Training Accuracy= 0.68750
# Iter 20, Minibatch Loss= 1.055537, Training Accuracy= 0.78516
# Iter 30, Minibatch Loss= 0.963917, Training Accuracy= 0.85156
# Iter 40, Minibatch Loss= 0.554650, Training Accuracy= 0.86328
# Iter 50, Minibatch Loss= 0.615745, Training Accuracy= 0.86719
# Iter 60, Minibatch Loss= 0.466320, Training Accuracy= 0.91016
# Iter 70, Minibatch Loss= 0.456979, Training Accuracy= 0.92969
# Iter 80, Minibatch Loss= 0.381748, Training Accuracy= 0.89453
# Iter 90, Minibatch Loss= 0.392191, Training Accuracy= 0.87891
# Iter 100, Minibatch Loss= 0.318070, Training Accuracy= 0.93359
# Iter 110, Minibatch Loss= 0.320216, Training Accuracy= 0.92188
# Iter 120, Minibatch Loss= 0.351340, Training Accuracy= 0.91406
# Iter 130, Minibatch Loss= 0.320061, Training Accuracy= 0.93359
# Iter 140, Minibatch Loss= 0.380079, Training Accuracy= 0.92578
# Iter 150, Minibatch Loss= 0.190657, Training Accuracy= 0.94531
# Iter 160, Minibatch Loss= 0.206040, Training Accuracy= 0.93750
# Iter 170, Minibatch Loss= 0.219785, Training Accuracy= 0.94141
# Iter 180, Minibatch Loss= 0.213141, Training Accuracy= 0.94531
# Iter 190, Minibatch Loss= 0.227372, Training Accuracy= 0.92578
# Optimization Finished!
# Testing Accuracy: 0.933594

# %% [markdown]
# # Listing 5-4 Sparse Auto Encoder Implementation in TensorFlow

# %%
import tensorflow as tf
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
import time

# Import MNIST data
from tensorflow.examples.tutorials.mnist import input_data
mnist = input_data.read_data_sets("MNIST_data", one_hot=True)

# Parameters
learning_rate = 0.001
training_epochs = 200
batch_size = 1000
display_step = 1
examples_to_show = 10

# Network Parameters
n_hidden_1 = 32*32 # 1st layer num features
#n_hidden_2 = 128 # 2nd layer num features
n_input = 784 # MNIST data input (img shape: 28*28)

# tf Graph input (only pictures)
X = tf.placeholder("float", [None, n_input])

weights = {
    'encoder_h1': tf.Variable(tf.random_normal([n_input, n_hidden_1])),
    
    'decoder_h1': tf.Variable(tf.random_normal([n_hidden_1,n_input])),
}    
biases = {
    'encoder_b1': tf.Variable(tf.random_normal([n_hidden_1])),
    'decoder_b1': tf.Variable(tf.random_normal([n_input])),
}


# Building the encoder
def encoder(x):
    # Encoder Hidden layer with sigmoid activation #1
    layer_1 = tf.nn.sigmoid(tf.add(tf.matmul(x, weights['encoder_h1']),
                                   biases['encoder_b1']))
    # Decoder Hidden layer with sigmoid activation #2
    
    return layer_1


# Building the decoder
def decoder(x):
    # Encoder Hidden layer with sigmoid activation #1
    layer_1 = tf.nn.sigmoid(tf.add(tf.matmul(x, tf.transpose(weights['encoder_h1'])),
                                   biases['decoder_b1']))
    # Decoder Hidden layer with sigmoid activation #2
    return layer_1

def logfunc(x, x2):
    return tf.multiply( x, tf.log(tf.div(x,x2)))

def KL_Div(rho, rho_hat):
    invrho = tf.subtract(tf.constant(1.), rho)
    invrhohat = tf.subtract(tf.constant(1.), rho_hat)
    logrho = logfunc(rho,rho_hat) + logfunc(invrho, invrhohat)
    return logrho


# Construct model
encoder_op = encoder(X)
decoder_op = decoder(encoder_op)
rho_hat = tf.reduce_mean(encoder_op,1)

# Prediction
y_pred = decoder_op
# Targets (Labels) are the input data.
y_true = X

# Define loss and optimizer, minimize the squared error
cost_m = tf.reduce_mean(tf.pow(y_true - y_pred, 2))
cost_sparse = 0.01*tf.reduce_sum(KL_Div(0.2,rho_hat))
#cost_reg = 0.0001* (tf.nn.l2_loss(weights['decoder_h1']) + tf.nn.l2_loss(weights['encoder_h1']))
cost_reg = 0.0001*tf.nn.l2_loss(weights['encoder_h1'])
cost = tf.add(cost_reg,tf.add(cost_m,cost_sparse))

optimizer = tf.train.RMSPropOptimizer(learning_rate).minimize(cost)

# Initializing the variables
init = tf.global_variables_initializer()

# Launch the graph
start_time = time.time()
with tf.Session() as sess:
    sess.run(init)
    total_batch = int(mnist.train.num_examples/batch_size)
    # Training cycle
    for epoch in range(training_epochs):
        # Loop over all batches
        for i in range(total_batch):
            batch_xs, batch_ys = mnist.train.next_batch(batch_size)
            # Run optimization op (backprop) and cost op (to get loss value)
            _, c = sess.run([optimizer, cost], feed_dict={X: batch_xs})
        # Display logs per epoch step
        if epoch % display_step == 0:
            print("Epoch:", '%04d' % (epoch+1),
                  "cost=", "{:.9f}".format(c))

    print("Optimization Finished!")

    # Applying encode and decode over test set
    encode_decode = sess.run(
        y_pred, feed_dict={X: mnist.test.images[:10]})
    # Compare original images with their reconstructions
    f, a = plt.subplots(2, 10, figsize=(10, 2))
    for i in range(10):
        a[0][i].imshow(np.reshape(mnist.test.images[i], (28, 28)),cmap='gray')
        a[1][i].imshow(np.reshape(encode_decode[i], (28, 28)),cmap='gray')
    #f.show()
    #plt.draw()
    #plt.waitforbuttonpress()
    #dec = sess.run(weights['decoder_h1'])
    enc = sess.run(weights['encoder_h1'])
end_time = time.time()
print('elapsed time:',end_time - start_time)
# Out:
# Extracting MNIST_data/train-images-idx3-ubyte.gz
# Extracting MNIST_data/train-labels-idx1-ubyte.gz
# Extracting MNIST_data/t10k-images-idx3-ubyte.gz
# Extracting MNIST_data/t10k-labels-idx1-ubyte.gz
# ('Epoch:', '0001', 'cost=', '42.452316284')
# ('Epoch:', '0002', 'cost=', '42.358757019')
# ('Epoch:', '0003', 'cost=', '40.977981567')
# ('Epoch:', '0004', 'cost=', '37.492420197')
# ('Epoch:', '0005', 'cost=', '34.189708710')
# ('Epoch:', '0006', 'cost=', '31.176343918')
# ('Epoch:', '0007', 'cost=', '28.381719589')
# ('Epoch:', '0008', 'cost=', '25.793050766')
# ('Epoch:', '0009', 'cost=', '23.396007538')
# ('Epoch:', '0010', 'cost=', '21.184881210')
# ('Epoch:', '0011', 'cost=', '19.143276215')
# ('Epoch:', '0012', 'cost=', '17.272615433')
# ('Epoch:', '0013', 'cost=', '15.554396629')
# ('Epoch:', '0014', 'cost=', '13.982030869')
# ('Epoch:', '0015', 'cost=', '12.546177864')
# ('Epoch:', '0016', 'cost=', '11.236365318')
# ('Epoch:', '0017', 'cost=', '10.041138649')
# ('Epoch:', '0018', 'cost=', '8.958015442')
# ('Epoch:', '0019', 'cost=', '7.975926399')
# ('Epoch:', '0020', 'cost=', '7.086833477')
# ('Epoch:', '0021', 'cost=', '6.285970211')
# ('Epoch:', '0022', 'cost=', '5.563276768')
# ('Epoch:', '0023', 'cost=', '4.915424824')
# ('Epoch:', '0024', 'cost=', '4.332758427')
# ('Epoch:', '0025', 'cost=', '3.811141968')
# ('Epoch:', '0026', 'cost=', '3.345531225')
# ('Epoch:', '0027', 'cost=', '2.930836916')
# ('Epoch:', '0028', 'cost=', '2.562726498')
# ('Epoch:', '0029', 'cost=', '2.236760139')
# ('Epoch:', '0030', 'cost=', '1.948493242')
# ('Epoch:', '0031', 'cost=', '1.694774508')
# ('Epoch:', '0032', 'cost=', '1.472238421')
# ('Epoch:', '0033', 'cost=', '1.276368737')
# ('Epoch:', '0034', 'cost=', '1.105563641')
# ('Epoch:', '0035', 'cost=', '0.956446886')
# ('Epoch:', '0036', 'cost=', '0.826719999')
# ('Epoch:', '0037', 'cost=', '0.714243412')
# ('Epoch:', '0038', 'cost=', '0.616989493')
# ('Epoch:', '0039', 'cost=', '0.532302737')
# ('Epoch:', '0040', 'cost=', '0.459788322')
# ('Epoch:', '0041', 'cost=', '0.397283822')
# ('Epoch:', '0042', 'cost=', '0.344012469')
# ('Epoch:', '0043', 'cost=', '0.297314644')
# ('Epoch:', '0044', 'cost=', '0.258120865')
# ('Epoch:', '0045', 'cost=', '0.225141183')
# ('Epoch:', '0046', 'cost=', '0.196277827')
# ('Epoch:', '0047', 'cost=', '0.171948105')
# ('Epoch:', '0048', 'cost=', '0.151500523')
# ('Epoch:', '0049', 'cost=', '0.133911520')
# ('Epoch:', '0050', 'cost=', '0.119393080')
# ('Epoch:', '0051', 'cost=', '0.107237145')
# ('Epoch:', '0052', 'cost=', '0.097197145')
# ('Epoch:', '0053', 'cost=', '0.088295192')
# ('Epoch:', '0054', 'cost=', '0.081085086')
# ('Epoch:', '0055', 'cost=', '0.075289056')
# ('Epoch:', '0056', 'cost=', '0.070761114')
# ('Epoch:', '0057', 'cost=', '0.066161424')
# ('Epoch:', '0058', 'cost=', '0.063012689')
# ('Epoch:', '0059', 'cost=', '0.059761621')
# ('Epoch:', '0060', 'cost=', '0.057177778')
# ('Epoch:', '0061', 'cost=', '0.055485301')
# ('Epoch:', '0062', 'cost=', '0.054165237')
# ('Epoch:', '0063', 'cost=', '0.052222244')
# ('Epoch:', '0064', 'cost=', '0.051667199')
# ('Epoch:', '0065', 'cost=', '0.051433850')
# ('Epoch:', '0066', 'cost=', '0.050449096')
# ('Epoch:', '0067', 'cost=', '0.048731662')
# ('Epoch:', '0068', 'cost=', '0.048809886')
# ('Epoch:', '0069', 'cost=', '0.047762718')
# ('Epoch:', '0070', 'cost=', '0.048310373')
# ('Epoch:', '0071', 'cost=', '0.047601357')
# ('Epoch:', '0072', 'cost=', '0.047975942')
# ('Epoch:', '0073', 'cost=', '0.047027659')
# ('Epoch:', '0074', 'cost=', '0.047339331')
# ('Epoch:', '0075', 'cost=', '0.047196615')
# ('Epoch:', '0076', 'cost=', '0.047313005')
# ('Epoch:', '0077', 'cost=', '0.046966851')
# ('Epoch:', '0078', 'cost=', '0.046272360')
# ('Epoch:', '0079', 'cost=', '0.046479885')
# ('Epoch:', '0080', 'cost=', '0.047044694')
# ('Epoch:', '0081', 'cost=', '0.046156168')
# ('Epoch:', '0082', 'cost=', '0.046403114')
# ('Epoch:', '0083', 'cost=', '0.046870559')
# ('Epoch:', '0084', 'cost=', '0.046314009')
# ('Epoch:', '0085', 'cost=', '0.046269685')
# ('Epoch:', '0086', 'cost=', '0.046198107')
# ('Epoch:', '0087', 'cost=', '0.046041410')
# ('Epoch:', '0088', 'cost=', '0.046179105')
# ('Epoch:', '0089', 'cost=', '0.046618354')
# ('Epoch:', '0090', 'cost=', '0.046682350')
# ('Epoch:', '0091', 'cost=', '0.045855001')
# ('Epoch:', '0092', 'cost=', '0.045848098')
# ('Epoch:', '0093', 'cost=', '0.045561571')
# ('Epoch:', '0094', 'cost=', '0.045993298')
# ('Epoch:', '0095', 'cost=', '0.045998912')
# ('Epoch:', '0096', 'cost=', '0.045801338')
# ('Epoch:', '0097', 'cost=', '0.046242006')
# ('Epoch:', '0098', 'cost=', '0.045639787')
# ('Epoch:', '0099', 'cost=', '0.045539215')
# ('Epoch:', '0100', 'cost=', '0.046153881')
# ('Epoch:', '0101', 'cost=', '0.046165694')
# ('Epoch:', '0102', 'cost=', '0.045654785')
# ('Epoch:', '0103', 'cost=', '0.045724571')
# ('Epoch:', '0104', 'cost=', '0.045470499')
# ('Epoch:', '0105', 'cost=', '0.045805141')
# ('Epoch:', '0106', 'cost=', '0.046107829')
# ('Epoch:', '0107', 'cost=', '0.045534037')
# ('Epoch:', '0108', 'cost=', '0.046043228')
# ('Epoch:', '0109', 'cost=', '0.045938708')
# ('Epoch:', '0110', 'cost=', '0.045683511')
# ('Epoch:', '0111', 'cost=', '0.045332905')
# ('Epoch:', '0112', 'cost=', '0.045374982')
# ('Epoch:', '0113', 'cost=', '0.045344356')
# ('Epoch:', '0114', 'cost=', '0.046184573')
# ('Epoch:', '0115', 'cost=', '0.045653678')
# ('Epoch:', '0116', 'cost=', '0.045060061')
# ('Epoch:', '0117', 'cost=', '0.045521561')
# ('Epoch:', '0118', 'cost=', '0.045799702')
# ('Epoch:', '0119', 'cost=', '0.045675494')
# ('Epoch:', '0120', 'cost=', '0.045742631')
# ('Epoch:', '0121', 'cost=', '0.045453466')
# ('Epoch:', '0122', 'cost=', '0.045819342')
# ('Epoch:', '0123', 'cost=', '0.045128021')
# ('Epoch:', '0124', 'cost=', '0.045256160')
# ('Epoch:', '0125', 'cost=', '0.045542415')
# ('Epoch:', '0126', 'cost=', '0.045442194')
# ('Epoch:', '0127', 'cost=', '0.045547847')
# ('Epoch:', '0128', 'cost=', '0.046307493')
# ('Epoch:', '0129', 'cost=', '0.045456555')
# ('Epoch:', '0130', 'cost=', '0.045160629')
# ('Epoch:', '0131', 'cost=', '0.045762673')
# ('Epoch:', '0132', 'cost=', '0.045447391')
# ('Epoch:', '0133', 'cost=', '0.044876702')
# ('Epoch:', '0134', 'cost=', '0.044977520')
# ('Epoch:', '0135', 'cost=', '0.045202136')
# ('Epoch:', '0136', 'cost=', '0.044750467')
# ('Epoch:', '0137', 'cost=', '0.044575356')
# ('Epoch:', '0138', 'cost=', '0.044982284')
# ('Epoch:', '0139', 'cost=', '0.045575976')
# ('Epoch:', '0140', 'cost=', '0.044951774')
# ('Epoch:', '0141', 'cost=', '0.045215234')
# ('Epoch:', '0142', 'cost=', '0.045182753')
# ('Epoch:', '0143', 'cost=', '0.045237262')
# ('Epoch:', '0144', 'cost=', '0.045481827')
# ('Epoch:', '0145', 'cost=', '0.045353219')
# ('Epoch:', '0146', 'cost=', '0.044803176')
# ('Epoch:', '0147', 'cost=', '0.045373451')
# ('Epoch:', '0148', 'cost=', '0.044654775')
# ('Epoch:', '0149', 'cost=', '0.044923294')
# ('Epoch:', '0150', 'cost=', '0.045113038')
# ('Epoch:', '0151', 'cost=', '0.044852927')
# ('Epoch:', '0152', 'cost=', '0.044958297')
# ('Epoch:', '0153', 'cost=', '0.044950299')
# ('Epoch:', '0154', 'cost=', '0.044728726')
# ('Epoch:', '0155', 'cost=', '0.044696655')
# ('Epoch:', '0156', 'cost=', '0.044513706')
# ('Epoch:', '0157', 'cost=', '0.044494595')
# ('Epoch:', '0158', 'cost=', '0.044482481')
# ('Epoch:', '0159', 'cost=', '0.044764973')
# ('Epoch:', '0160', 'cost=', '0.044863887')
# ('Epoch:', '0161', 'cost=', '0.044929594')
# ('Epoch:', '0162', 'cost=', '0.045162257')
# ('Epoch:', '0163', 'cost=', '0.044731408')
# ('Epoch:', '0164', 'cost=', '0.045381933')
# ('Epoch:', '0165', 'cost=', '0.045436613')
# ('Epoch:', '0166', 'cost=', '0.044502132')
# ('Epoch:', '0167', 'cost=', '0.045151159')
# ('Epoch:', '0168', 'cost=', '0.044473253')
# ('Epoch:', '0169', 'cost=', '0.045084558')
# ('Epoch:', '0170', 'cost=', '0.045374401')
# ('Epoch:', '0171', 'cost=', '0.045062646')
# ('Epoch:', '0172', 'cost=', '0.045052249')
# ('Epoch:', '0173', 'cost=', '0.045000210')
# ('Epoch:', '0174', 'cost=', '0.044201709')
# ('Epoch:', '0175', 'cost=', '0.044240162')
# ('Epoch:', '0176', 'cost=', '0.044523399')
# ('Epoch:', '0177', 'cost=', '0.045139678')
# ('Epoch:', '0178', 'cost=', '0.045077983')
# ('Epoch:', '0179', 'cost=', '0.044658914')
# ('Epoch:', '0180', 'cost=', '0.044643689')
# ('Epoch:', '0181', 'cost=', '0.044740442')
# ('Epoch:', '0182', 'cost=', '0.044742826')
# ('Epoch:', '0183', 'cost=', '0.044082046')
# ('Epoch:', '0184', 'cost=', '0.044333197')
# ('Epoch:', '0185', 'cost=', '0.044751797')
# ('Epoch:', '0186', 'cost=', '0.044566449')
# ('Epoch:', '0187', 'cost=', '0.045083486')
# ('Epoch:', '0188', 'cost=', '0.044602953')
# ('Epoch:', '0189', 'cost=', '0.045064118')
# ('Epoch:', '0190', 'cost=', '0.044703539')
# ('Epoch:', '0191', 'cost=', '0.044431202')
# ('Epoch:', '0192', 'cost=', '0.044511795')
# ('Epoch:', '0193', 'cost=', '0.044806734')
# ('Epoch:', '0194', 'cost=', '0.044533990')
# ('Epoch:', '0195', 'cost=', '0.044733904')
# ('Epoch:', '0196', 'cost=', '0.044380382')
# ('Epoch:', '0197', 'cost=', '0.044464108')
# ('Epoch:', '0198', 'cost=', '0.044623353')
# ('Epoch:', '0199', 'cost=', '0.044629999')
# ('Epoch:', '0200', 'cost=', '0.044612192')
# Optimization Finished!
# ('elapsed time:', 60.956778049468994)

# %% [markdown]
# # Plot of the Sparse feature weights learnt

# %%
img_coll = []
for i in xrange(1024):
    img = np.array(enc.T[i,:])
    img = np.reshape(img,(28,28))
    img_coll.append(img)

img_coll = np.array(img_coll)
f, a = plt.subplots(10, 10, figsize=(10, 10))
for i in range(10):
        a[0][i].imshow(np.reshape(img_coll[i], (28, 28)),cmap='gray')
        a[1][i].imshow(np.reshape(img_coll[10 + i], (28, 28)),cmap='gray')
        a[2][i].imshow(np.reshape(img_coll[20 + i], (28, 28)),cmap='gray')
        a[3][i].imshow(np.reshape(img_coll[30 + i], (28, 28)),cmap='gray')
        a[4][i].imshow(np.reshape(img_coll[40 + i], (28, 28)),cmap='gray')
        a[5][i].imshow(np.reshape(img_coll[50 + i], (28, 28)),cmap='gray')
        a[6][i].imshow(np.reshape(img_coll[60 + i], (28, 28)),cmap='gray')
        a[7][i].imshow(np.reshape(img_coll[70 + i], (28, 28)),cmap='gray')
        a[8][i].imshow(np.reshape(img_coll[80 + i], (28, 28)),cmap='gray')
        a[9][i].imshow(np.reshape(img_coll[90 + i], (28, 28)),cmap='gray')

# %% [markdown]
# # Listing 5-5 Denoising Auto Encoder Implementation in TensorFlow

# %% [markdown]
# # Remove the Guassian Noise

# %%
# Import the required library

import tensorflow.contrib.layers as lays
import numpy as np
from skimage import transform
import tensorflow as tf
from tensorflow.examples.tutorials.mnist import input_data
import matplotlib.pyplot as plt 

def autoencoder(inputs):
    # encoder
    # 32 x 32 x 1   ->  16 x 16 x 32
    # 16 x 16 x 32  ->  8 x 8 x 16
    # 8 x 8 x 16    ->  2 x 2 x 8
    net = lays.conv2d(inputs, 32, [5, 5], stride=2, padding='SAME')
    net = lays.conv2d(net, 16, [5, 5], stride=2, padding='SAME')
    net = lays.conv2d(net, 8, [5, 5], stride=4, padding='SAME')
    # decoder
    # 2 x 2 x 8    ->  8 x 8 x 16
    # 8 x 8 x 16   ->  16 x 16 x 32
    # 16 x 16 x 32  ->  32 x 32 x 1
    net = lays.conv2d_transpose(net, 16, [5, 5], stride=4, padding='SAME')
    net = lays.conv2d_transpose(net, 32, [5, 5], stride=2, padding='SAME')
    net = lays.conv2d_transpose(net, 1, [5, 5], stride=2, padding='SAME', activation_fn=tf.nn.tanh)
    return net

def resize_batch(imgs):
    # A function to resize a batch of MNIST images to (32, 32)
    # Args:
    #   imgs: a numpy array of size [batch_size, 28 X 28].
    # Returns:
    #   a numpy array of size [batch_size, 32, 32].
    imgs = imgs.reshape((-1, 28, 28, 1))
    resized_imgs = np.zeros((imgs.shape[0], 32, 32, 1))
    for i in range(imgs.shape[0]):
        resized_imgs[i, ..., 0] = transform.resize(imgs[i, ..., 0], (32, 32))
    return resized_imgs

# Introduce Gaussian Noise
def noisy(image):
    row,col= image.shape
    mean = 0
    var = 0.1
    sigma = var**0.5
    gauss = np.random.normal(mean,sigma,(row,col))
    gauss = gauss.reshape(row,col)
    noisy = image + gauss
    return noisy
    

# Introduce Salt and Pepper Noise
def s_p(image):
    row,col = image.shape
    s_vs_p = 0.5
    amount = 0.05
    out = np.copy(image)
      # Salt mode
    num_salt = np.ceil(amount * image.size * s_vs_p)
    coords = [np.random.randint(0, i - 1, int(num_salt)) for i in image.shape]
    out[coords] = 1

      # Pepper mode
    num_pepper = np.ceil(amount* image.size * (1. - s_vs_p))
    coords = [np.random.randint(0, i - 1, int(num_pepper)) for i in image.shape]
    out[coords] = 0
    return out

ae_inputs = tf.placeholder(tf.float32, (None, 32, 32, 1))  # input to the network (MNIST images)
ae_inputs_noise = tf.placeholder(tf.float32, (None, 32, 32, 1)) 
ae_outputs = autoencoder(ae_inputs_noise)  # create the Autoencoder network

# calculate the loss and optimize the network
loss = tf.reduce_mean(tf.square(ae_outputs - ae_inputs))  # claculate the mean square error loss
train_op = tf.train.AdamOptimizer(learning_rate=0.001).minimize(loss)

# initialize the network
init = tf.global_variables_initializer()

batch_size = 500  # Number of samples in each batch
epoch_num = 5     # Number of epochs to train the network
lr = 0.001        # Learning rate

# read MNIST dataset
mnist = input_data.read_data_sets("MNIST_data", one_hot=True)

# calculate the number of batches per epoch
batch_per_ep = mnist.train.num_examples // batch_size

with tf.Session() as sess:
    sess.run(init)
    for ep in range(epoch_num):  # epochs loop
        for batch_n in range(batch_per_ep):  # batches loop
            batch_img, batch_label = mnist.train.next_batch(batch_size)  # read a batch
            batch_img = batch_img.reshape((-1, 28, 28, 1))               # reshape each sample to an (28, 28) image
            batch_img = resize_batch(batch_img)                          # reshape the images to (32, 32)
            image_arr = []
            for i in xrange(len(batch_img)):
                img = batch_img[i,:,:,0]
                img = noisy(img)
                image_arr.append(img)
            image_arr = np.array(image_arr)
            image_arr = image_arr.reshape(-1,32,32,1)
            batch_img = image_arr
            _, c = sess.run([train_op, loss], feed_dict={ae_inputs: batch_img,ae_inputs_noise:image_arr})
            print('Epoch: {} - cost= {:.5f}'.format((ep + 1), c))

    # test the trained network
    batch_img, batch_label = mnist.test.next_batch(50)
    batch_img = resize_batch(batch_img)
    image_arr = []
    
    for i in xrange(50):
        img = batch_img[i,:,:,0]
        img = noisy(img)
        image_arr.append(img)
    image_arr = np.array(image_arr)
    image_arr = image_arr.reshape(-1,32,32,1)
    batch_img = image_arr
            
    recon_img = sess.run([ae_outputs], feed_dict={ae_inputs_noise: batch_img})[0]

    # plot the reconstructed images and their ground truths (inputs)
    plt.figure(1)
    plt.title('Reconstructed Images')
    for i in range(50):
        plt.subplot(5, 10, i+1)
        plt.imshow(recon_img[i, ..., 0], cmap='gray')
    plt.figure(2)
    plt.title('Input Images with Gaussian Noise')
    for i in range(50):
        plt.subplot(5, 10, i+1)
        plt.imshow(batch_img[i, ..., 0], cmap='gray')
    plt.show()
# Out:
# Extracting MNIST_data/train-images-idx3-ubyte.gz
# Extracting MNIST_data/train-labels-idx1-ubyte.gz
# Extracting MNIST_data/t10k-images-idx3-ubyte.gz
# Extracting MNIST_data/t10k-labels-idx1-ubyte.gz
# Epoch: 1 - cost= 0.21037
# Epoch: 1 - cost= 0.20408
# Epoch: 1 - cost= 0.21502
# Epoch: 1 - cost= 0.19098
# Epoch: 1 - cost= 0.18185
# Epoch: 1 - cost= 0.19519
# Epoch: 1 - cost= 0.19629
# Epoch: 1 - cost= 0.19690
# Epoch: 1 - cost= 0.18144
# Epoch: 1 - cost= 0.17870
# Epoch: 1 - cost= 0.18364
# Epoch: 1 - cost= 0.17456
# Epoch: 1 - cost= 0.17836
# Epoch: 1 - cost= 0.17644
# Epoch: 1 - cost= 0.17816
# Epoch: 1 - cost= 0.17119
# Epoch: 1 - cost= 0.17413
# Epoch: 1 - cost= 0.16603
# Epoch: 1 - cost= 0.17288
# Epoch: 1 - cost= 0.16467
# Epoch: 1 - cost= 0.16056
# Epoch: 1 - cost= 0.16299
# Epoch: 1 - cost= 0.16419
# Epoch: 1 - cost= 0.15930
# Epoch: 1 - cost= 0.16324
# Epoch: 1 - cost= 0.15614
# Epoch: 1 - cost= 0.15742
# Epoch: 1 - cost= 0.15882
# Epoch: 1 - cost= 0.16121
# Epoch: 1 - cost= 0.16360
# Epoch: 1 - cost= 0.15918
# Epoch: 1 - cost= 0.15881
# Epoch: 1 - cost= 0.15781
# Epoch: 1 - cost= 0.15673
# Epoch: 1 - cost= 0.15640
# Epoch: 1 - cost= 0.15958
# Epoch: 1 - cost= 0.15785
# Epoch: 1 - cost= 0.15461
# Epoch: 1 - cost= 0.15435
# Epoch: 1 - cost= 0.15252
# Epoch: 1 - cost= 0.15498
# Epoch: 1 - cost= 0.15109
# Epoch: 1 - cost= 0.15123
# Epoch: 1 - cost= 0.15113
# Epoch: 1 - cost= 0.15564
# Epoch: 1 - cost= 0.15077
# Epoch: 1 - cost= 0.15528
# Epoch: 1 - cost= 0.15408
# Epoch: 1 - cost= 0.15186
# Epoch: 1 - cost= 0.14770
# Epoch: 1 - cost= 0.15169
# Epoch: 1 - cost= 0.14643
# Epoch: 1 - cost= 0.14860
# Epoch: 1 - cost= 0.14878
# Epoch: 1 - cost= 0.15276
# Epoch: 1 - cost= 0.14925
# Epoch: 1 - cost= 0.15091
# Epoch: 1 - cost= 0.14656
# Epoch: 1 - cost= 0.14930
# Epoch: 1 - cost= 0.14984
# Epoch: 1 - cost= 0.14841
# Epoch: 1 - cost= 0.14732
# Epoch: 1 - cost= 0.14925
# Epoch: 1 - cost= 0.14853
# Epoch: 1 - cost= 0.14791
# Epoch: 1 - cost= 0.14743
# Epoch: 1 - cost= 0.14552
# Epoch: 1 - cost= 0.14648
# Epoch: 1 - cost= 0.14633
# Epoch: 1 - cost= 0.14358
# Epoch: 1 - cost= 0.14542
# Epoch: 1 - cost= 0.14486
# Epoch: 1 - cost= 0.14462
# Epoch: 1 - cost= 0.14036
# Epoch: 1 - cost= 0.14381
# Epoch: 1 - cost= 0.14352
# Epoch: 1 - cost= 0.14123
# Epoch: 1 - cost= 0.14059
# Epoch: 1 - cost= 0.14221
# Epoch: 1 - cost= 0.14046
# Epoch: 1 - cost= 0.14192
# Epoch: 1 - cost= 0.13872
# Epoch: 1 - cost= 0.13861
# Epoch: 1 - cost= 0.14113
# Epoch: 1 - cost= 0.13790
# Epoch: 1 - cost= 0.14074
# Epoch: 1 - cost= 0.13969
# Epoch: 1 - cost= 0.13823
# Epoch: 1 - cost= 0.13904
# Epoch: 1 - cost= 0.13753
# Epoch: 1 - cost= 0.13625
# Epoch: 1 - cost= 0.13652
# Epoch: 1 - cost= 0.13650
# Epoch: 1 - cost= 0.13535
# Epoch: 1 - cost= 0.13373
# Epoch: 1 - cost= 0.13511
# Epoch: 1 - cost= 0.13443
# Epoch: 1 - cost= 0.13378
# Epoch: 1 - cost= 0.13397
# Epoch: 1 - cost= 0.13401
# Epoch: 1 - cost= 0.13243
# Epoch: 1 - cost= 0.13359
# Epoch: 1 - cost= 0.13149
# Epoch: 1 - cost= 0.13340
# Epoch: 1 - cost= 0.13187
# Epoch: 1 - cost= 0.13199
# Epoch: 1 - cost= 0.13234
# Epoch: 1 - cost= 0.13063
# Epoch: 1 - cost= 0.13229
# Epoch: 1 - cost= 0.13036
# Epoch: 2 - cost= 0.12985
# Epoch: 2 - cost= 0.12930
# Epoch: 2 - cost= 0.12963
# Epoch: 2 - cost= 0.12922
# Epoch: 2 - cost= 0.12897
# Epoch: 2 - cost= 0.12859
# Epoch: 2 - cost= 0.12829
# Epoch: 2 - cost= 0.12748
# Epoch: 2 - cost= 0.12751
# Epoch: 2 - cost= 0.12725
# Epoch: 2 - cost= 0.12672
# Epoch: 2 - cost= 0.12654
# Epoch: 2 - cost= 0.12638
# Epoch: 2 - cost= 0.12660
# Epoch: 2 - cost= 0.12693
# Epoch: 2 - cost= 0.12514
# Epoch: 2 - cost= 0.12560
# Epoch: 2 - cost= 0.12549
# Epoch: 2 - cost= 0.12535
# Epoch: 2 - cost= 0.12570
# Epoch: 2 - cost= 0.12423
# Epoch: 2 - cost= 0.12444
# Epoch: 2 - cost= 0.12411
# Epoch: 2 - cost= 0.12357
# Epoch: 2 - cost= 0.12384
# Epoch: 2 - cost= 0.12345
# Epoch: 2 - cost= 0.12347
# Epoch: 2 - cost= 0.12378
# Epoch: 2 - cost= 0.12258
# Epoch: 2 - cost= 0.12247
# Epoch: 2 - cost= 0.12109
# Epoch: 2 - cost= 0.12199
# Epoch: 2 - cost= 0.12155
# Epoch: 2 - cost= 0.12208
# Epoch: 2 - cost= 0.12189
# Epoch: 2 - cost= 0.12211
# Epoch: 2 - cost= 0.12176
# Epoch: 2 - cost= 0.12096
# Epoch: 2 - cost= 0.12118
# Epoch: 2 - cost= 0.12084
# Epoch: 2 - cost= 0.12100
# Epoch: 2 - cost= 0.12039
# Epoch: 2 - cost= 0.12031
# Epoch: 2 - cost= 0.12050
# Epoch: 2 - cost= 0.11971
# Epoch: 2 - cost= 0.12019
# Epoch: 2 - cost= 0.11966
# Epoch: 2 - cost= 0.11956
# Epoch: 2 - cost= 0.12001
# Epoch: 2 - cost= 0.11987
# Epoch: 2 - cost= 0.11933
# Epoch: 2 - cost= 0.11896
# Epoch: 2 - cost= 0.11906
# Epoch: 2 - cost= 0.11924
# Epoch: 2 - cost= 0.11888
# Epoch: 2 - cost= 0.11921
# Epoch: 2 - cost= 0.11822
# Epoch: 2 - cost= 0.11871
# Epoch: 2 - cost= 0.11816
# Epoch: 2 - cost= 0.11930
# Epoch: 2 - cost= 0.11713
# Epoch: 2 - cost= 0.11790
# Epoch: 2 - cost= 0.11782
# Epoch: 2 - cost= 0.11777
# Epoch: 2 - cost= 0.11789
# Epoch: 2 - cost= 0.11759
# Epoch: 2 - cost= 0.11780
# Epoch: 2 - cost= 0.11770
# Epoch: 2 - cost= 0.11782
# Epoch: 2 - cost= 0.11775
# Epoch: 2 - cost= 0.11786
# Epoch: 2 - cost= 0.11714
# Epoch: 2 - cost= 0.11744
# Epoch: 2 - cost= 0.11730
# Epoch: 2 - cost= 0.11717
# Epoch: 2 - cost= 0.11697
# Epoch: 2 - cost= 0.11692
# Epoch: 2 - cost= 0.11680
# Epoch: 2 - cost= 0.11664
# Epoch: 2 - cost= 0.11636
# Epoch: 2 - cost= 0.11622
# Epoch: 2 - cost= 0.11729
# Epoch: 2 - cost= 0.11587
# Epoch: 2 - cost= 0.11663
# Epoch: 2 - cost= 0.11691
# Epoch: 2 - cost= 0.11647
# Epoch: 2 - cost= 0.11601
# Epoch: 2 - cost= 0.11619
# Epoch: 2 - cost= 0.11586
# Epoch: 2 - cost= 0.11550
# Epoch: 2 - cost= 0.11573
# Epoch: 2 - cost= 0.11621
# Epoch: 2 - cost= 0.11524
# Epoch: 2 - cost= 0.11652
# Epoch: 2 - cost= 0.11606
# Epoch: 2 - cost= 0.11480
# Epoch: 2 - cost= 0.11569
# Epoch: 2 - cost= 0.11600
# Epoch: 2 - cost= 0.11505
# Epoch: 2 - cost= 0.11646
# Epoch: 2 - cost= 0.11506
# Epoch: 2 - cost= 0.11542
# Epoch: 2 - cost= 0.11500
# Epoch: 2 - cost= 0.11529
# Epoch: 2 - cost= 0.11495
# Epoch: 2 - cost= 0.11520
# Epoch: 2 - cost= 0.11516
# Epoch: 2 - cost= 0.11514
# Epoch: 2 - cost= 0.11517
# Epoch: 2 - cost= 0.11481
# Epoch: 3 - cost= 0.11453
# Epoch: 3 - cost= 0.11514
# Epoch: 3 - cost= 0.11462
# Epoch: 3 - cost= 0.11459
# Epoch: 3 - cost= 0.11477
# Epoch: 3 - cost= 0.11449
# Epoch: 3 - cost= 0.11477
# Epoch: 3 - cost= 0.11354
# Epoch: 3 - cost= 0.11423
# Epoch: 3 - cost= 0.11446
# Epoch: 3 - cost= 0.11402
# Epoch: 3 - cost= 0.11413
# Epoch: 3 - cost= 0.11451
# Epoch: 3 - cost= 0.11409
# Epoch: 3 - cost= 0.11398
# Epoch: 3 - cost= 0.11419
# Epoch: 3 - cost= 0.11402
# Epoch: 3 - cost= 0.11391
# Epoch: 3 - cost= 0.11405
# Epoch: 3 - cost= 0.11408
# Epoch: 3 - cost= 0.11387
# Epoch: 3 - cost= 0.11380
# Epoch: 3 - cost= 0.11424
# Epoch: 3 - cost= 0.11415
# Epoch: 3 - cost= 0.11391
# Epoch: 3 - cost= 0.11394
# Epoch: 3 - cost= 0.11380
# Epoch: 3 - cost= 0.11356
# Epoch: 3 - cost= 0.11384
# Epoch: 3 - cost= 0.11358
# Epoch: 3 - cost= 0.11397
# Epoch: 3 - cost= 0.11403
# Epoch: 3 - cost= 0.11382
# Epoch: 3 - cost= 0.11293
# Epoch: 3 - cost= 0.11349
# Epoch: 3 - cost= 0.11320
# Epoch: 3 - cost= 0.11306
# Epoch: 3 - cost= 0.11300
# Epoch: 3 - cost= 0.11305
# Epoch: 3 - cost= 0.11362
# Epoch: 3 - cost= 0.11342
# Epoch: 3 - cost= 0.11282
# Epoch: 3 - cost= 0.11334
# Epoch: 3 - cost= 0.11322
# Epoch: 3 - cost= 0.11264
# Epoch: 3 - cost= 0.11351
# Epoch: 3 - cost= 0.11284
# Epoch: 3 - cost= 0.11308
# Epoch: 3 - cost= 0.11325
# Epoch: 3 - cost= 0.11283
# Epoch: 3 - cost= 0.11277
# Epoch: 3 - cost= 0.11329
# Epoch: 3 - cost= 0.11319
# Epoch: 3 - cost= 0.11286
# Epoch: 3 - cost= 0.11269
# Epoch: 3 - cost= 0.11264
# Epoch: 3 - cost= 0.11239
# Epoch: 3 - cost= 0.11264
# Epoch: 3 - cost= 0.11239
# Epoch: 3 - cost= 0.11253
# Epoch: 3 - cost= 0.11254
# Epoch: 3 - cost= 0.11278
# Epoch: 3 - cost= 0.11275
# Epoch: 3 - cost= 0.11274
# Epoch: 3 - cost= 0.11260
# Epoch: 3 - cost= 0.11238
# Epoch: 3 - cost= 0.11263
# Epoch: 3 - cost= 0.11298
# Epoch: 3 - cost= 0.11262
# Epoch: 3 - cost= 0.11216
# Epoch: 3 - cost= 0.11186
# Epoch: 3 - cost= 0.11262
# Epoch: 3 - cost= 0.11250
# Epoch: 3 - cost= 0.11207
# Epoch: 3 - cost= 0.11210
# Epoch: 3 - cost= 0.11196
# Epoch: 3 - cost= 0.11167
# Epoch: 3 - cost= 0.11274
# Epoch: 3 - cost= 0.11182
# Epoch: 3 - cost= 0.11224
# Epoch: 3 - cost= 0.11153
# Epoch: 3 - cost= 0.11174
# Epoch: 3 - cost= 0.11209
# Epoch: 3 - cost= 0.11175
# Epoch: 3 - cost= 0.11225
# Epoch: 3 - cost= 0.11233
# Epoch: 3 - cost= 0.11201
# Epoch: 3 - cost= 0.11240
# Epoch: 3 - cost= 0.11152
# Epoch: 3 - cost= 0.11174
# Epoch: 3 - cost= 0.11168
# Epoch: 3 - cost= 0.11143
# Epoch: 3 - cost= 0.11225
# Epoch: 3 - cost= 0.11169
# Epoch: 3 - cost= 0.11146
# Epoch: 3 - cost= 0.11184
# Epoch: 3 - cost= 0.11180
# Epoch: 3 - cost= 0.11113
# Epoch: 3 - cost= 0.11201
# Epoch: 3 - cost= 0.11132
# Epoch: 3 - cost= 0.11168
# Epoch: 3 - cost= 0.11091
# Epoch: 3 - cost= 0.11157
# Epoch: 3 - cost= 0.11128
# Epoch: 3 - cost= 0.11167
# Epoch: 3 - cost= 0.11170
# Epoch: 3 - cost= 0.11091
# Epoch: 3 - cost= 0.11121
# Epoch: 3 - cost= 0.11129
# Epoch: 3 - cost= 0.11118
# Epoch: 4 - cost= 0.11130
# Epoch: 4 - cost= 0.11094
# Epoch: 4 - cost= 0.11118
# Epoch: 4 - cost= 0.11099
# Epoch: 4 - cost= 0.11105
# Epoch: 4 - cost= 0.11083
# Epoch: 4 - cost= 0.11102
# Epoch: 4 - cost= 0.11157
# Epoch: 4 - cost= 0.11106
# Epoch: 4 - cost= 0.11113
# Epoch: 4 - cost= 0.11110
# Epoch: 4 - cost= 0.11118
# Epoch: 4 - cost= 0.11139
# Epoch: 4 - cost= 0.11046
# Epoch: 4 - cost= 0.11055
# Epoch: 4 - cost= 0.11070
# Epoch: 4 - cost= 0.11073
# Epoch: 4 - cost= 0.11033
# Epoch: 4 - cost= 0.11102
# Epoch: 4 - cost= 0.11081
# Epoch: 4 - cost= 0.11129
# Epoch: 4 - cost= 0.11057
# Epoch: 4 - cost= 0.11055
# Epoch: 4 - cost= 0.11067
# Epoch: 4 - cost= 0.11101
# Epoch: 4 - cost= 0.11068
# Epoch: 4 - cost= 0.11136
# Epoch: 4 - cost= 0.11042
# Epoch: 4 - cost= 0.11078
# Epoch: 4 - cost= 0.11131
# Epoch: 4 - cost= 0.11095
# Epoch: 4 - cost= 0.11069
# Epoch: 4 - cost= 0.11078
# Epoch: 4 - cost= 0.11089
# Epoch: 4 - cost= 0.11045
# Epoch: 4 - cost= 0.11093
# Epoch: 4 - cost= 0.11082
# Epoch: 4 - cost= 0.11123
# Epoch: 4 - cost= 0.11059
# Epoch: 4 - cost= 0.11135
# Epoch: 4 - cost= 0.11059
# Epoch: 4 - cost= 0.11030
# Epoch: 4 - cost= 0.11116
# Epoch: 4 - cost= 0.11012
# Epoch: 4 - cost= 0.11039
# Epoch: 4 - cost= 0.11029
# Epoch: 4 - cost= 0.11069
# Epoch: 4 - cost= 0.10999
# Epoch: 4 - cost= 0.11050
# Epoch: 4 - cost= 0.11080
# Epoch: 4 - cost= 0.11062
# Epoch: 4 - cost= 0.11028
# Epoch: 4 - cost= 0.11040
# Epoch: 4 - cost= 0.10991
# Epoch: 4 - cost= 0.11059
# Epoch: 4 - cost= 0.10999
# Epoch: 4 - cost= 0.11038
# Epoch: 4 - cost= 0.10996
# Epoch: 4 - cost= 0.11095
# Epoch: 4 - cost= 0.11058
# Epoch: 4 - cost= 0.11006
# Epoch: 4 - cost= 0.11007
# Epoch: 4 - cost= 0.11007
# Epoch: 4 - cost= 0.11016
# Epoch: 4 - cost= 0.11059
# Epoch: 4 - cost= 0.11029
# Epoch: 4 - cost= 0.11018
# Epoch: 4 - cost= 0.10976
# Epoch: 4 - cost= 0.11057
# Epoch: 4 - cost= 0.11082
# Epoch: 4 - cost= 0.11063
# Epoch: 4 - cost= 0.10986
# Epoch: 4 - cost= 0.11020
# Epoch: 4 - cost= 0.10969
# Epoch: 4 - cost= 0.11025
# Epoch: 4 - cost= 0.11024
# Epoch: 4 - cost= 0.11005
# Epoch: 4 - cost= 0.10961
# Epoch: 4 - cost= 0.11014
# Epoch: 4 - cost= 0.10986
# Epoch: 4 - cost= 0.11006
# Epoch: 4 - cost= 0.10946
# Epoch: 4 - cost= 0.11041
# Epoch: 4 - cost= 0.11005
# Epoch: 4 - cost= 0.11040
# Epoch: 4 - cost= 0.10980
# Epoch: 4 - cost= 0.10963
# Epoch: 4 - cost= 0.10945
# Epoch: 4 - cost= 0.10960
# Epoch: 4 - cost= 0.10976
# Epoch: 4 - cost= 0.11000
# Epoch: 4 - cost= 0.10965
# Epoch: 4 - cost= 0.10985
# Epoch: 4 - cost= 0.10989
# Epoch: 4 - cost= 0.10957
# Epoch: 4 - cost= 0.10955
# Epoch: 4 - cost= 0.10927
# Epoch: 4 - cost= 0.10936
# Epoch: 4 - cost= 0.10985
# Epoch: 4 - cost= 0.10956
# Epoch: 4 - cost= 0.10919
# Epoch: 4 - cost= 0.10932
# Epoch: 4 - cost= 0.10953
# Epoch: 4 - cost= 0.10917
# Epoch: 4 - cost= 0.10925
# Epoch: 4 - cost= 0.10916
# Epoch: 4 - cost= 0.10963
# Epoch: 4 - cost= 0.10969
# Epoch: 4 - cost= 0.10971
# Epoch: 4 - cost= 0.10978
# Epoch: 5 - cost= 0.11037
# Epoch: 5 - cost= 0.11014
# Epoch: 5 - cost= 0.10968
# Epoch: 5 - cost= 0.10956
# Epoch: 5 - cost= 0.10913
# Epoch: 5 - cost= 0.10959
# Epoch: 5 - cost= 0.10930
# Epoch: 5 - cost= 0.10966
# Epoch: 5 - cost= 0.10957
# Epoch: 5 - cost= 0.10946
# Epoch: 5 - cost= 0.10916
# Epoch: 5 - cost= 0.10956
# Epoch: 5 - cost= 0.11007
# Epoch: 5 - cost= 0.10964
# Epoch: 5 - cost= 0.10918
# Epoch: 5 - cost= 0.10958
# Epoch: 5 - cost= 0.10919
# Epoch: 5 - cost= 0.10926
# Epoch: 5 - cost= 0.10988
# Epoch: 5 - cost= 0.10873
# Epoch: 5 - cost= 0.10908
# Epoch: 5 - cost= 0.10899
# Epoch: 5 - cost= 0.10963
# Epoch: 5 - cost= 0.10910
# Epoch: 5 - cost= 0.10913
# Epoch: 5 - cost= 0.10898
# Epoch: 5 - cost= 0.10973
# Epoch: 5 - cost= 0.10902
# Epoch: 5 - cost= 0.10932
# Epoch: 5 - cost= 0.10933
# Epoch: 5 - cost= 0.10845
# Epoch: 5 - cost= 0.10913
# Epoch: 5 - cost= 0.10912
# Epoch: 5 - cost= 0.10924
# Epoch: 5 - cost= 0.10927
# Epoch: 5 - cost= 0.10885
# Epoch: 5 - cost= 0.10902
# Epoch: 5 - cost= 0.10895
# Epoch: 5 - cost= 0.10884
# Epoch: 5 - cost= 0.10869
# Epoch: 5 - cost= 0.10893
# Epoch: 5 - cost= 0.10935
# Epoch: 5 - cost= 0.10892
# Epoch: 5 - cost= 0.10892
# Epoch: 5 - cost= 0.10805
# Epoch: 5 - cost= 0.10916
# Epoch: 5 - cost= 0.10895
# Epoch: 5 - cost= 0.10865
# Epoch: 5 - cost= 0.10916
# Epoch: 5 - cost= 0.10919
# Epoch: 5 - cost= 0.10867
# Epoch: 5 - cost= 0.10854
# Epoch: 5 - cost= 0.10911
# Epoch: 5 - cost= 0.10826
# Epoch: 5 - cost= 0.10909
# Epoch: 5 - cost= 0.10907
# Epoch: 5 - cost= 0.10868
# Epoch: 5 - cost= 0.10884
# Epoch: 5 - cost= 0.10901
# Epoch: 5 - cost= 0.10876
# Epoch: 5 - cost= 0.10829
# Epoch: 5 - cost= 0.10898
# Epoch: 5 - cost= 0.10862
# Epoch: 5 - cost= 0.10851
# Epoch: 5 - cost= 0.10901
# Epoch: 5 - cost= 0.10924
# Epoch: 5 - cost= 0.10892
# Epoch: 5 - cost= 0.10830
# Epoch: 5 - cost= 0.10932
# Epoch: 5 - cost= 0.10839
# Epoch: 5 - cost= 0.10897
# Epoch: 5 - cost= 0.10852
# Epoch: 5 - cost= 0.10886
# Epoch: 5 - cost= 0.10847
# Epoch: 5 - cost= 0.10869
# Epoch: 5 - cost= 0.10826
# Epoch: 5 - cost= 0.10897
# Epoch: 5 - cost= 0.10850
# Epoch: 5 - cost= 0.10850
# Epoch: 5 - cost= 0.10932
# Epoch: 5 - cost= 0.10801
# Epoch: 5 - cost= 0.10872
# Epoch: 5 - cost= 0.10925
# Epoch: 5 - cost= 0.10903
# Epoch: 5 - cost= 0.10851
# Epoch: 5 - cost= 0.10913
# Epoch: 5 - cost= 0.10814
# Epoch: 5 - cost= 0.10886
# Epoch: 5 - cost= 0.10814
# Epoch: 5 - cost= 0.10868
# Epoch: 5 - cost= 0.10868
# Epoch: 5 - cost= 0.10799
# Epoch: 5 - cost= 0.10852
# Epoch: 5 - cost= 0.10824
# Epoch: 5 - cost= 0.10844
# Epoch: 5 - cost= 0.10868
# Epoch: 5 - cost= 0.10845
# Epoch: 5 - cost= 0.10833
# Epoch: 5 - cost= 0.10847
# Epoch: 5 - cost= 0.10870
# Epoch: 5 - cost= 0.10838
# Epoch: 5 - cost= 0.10827
# Epoch: 5 - cost= 0.10868
# Epoch: 5 - cost= 0.10852
# Epoch: 5 - cost= 0.10866
# Epoch: 5 - cost= 0.10839
# Epoch: 5 - cost= 0.10911
# Epoch: 5 - cost= 0.10803
# Epoch: 5 - cost= 0.10823
# Epoch: 5 - cost= 0.10826

# %% [markdown]
# # Remove the Salt and Pepper Noise

# %%
batch_size = 1000  # Number of samples in each batch
epoch_num = 10     # Number of epochs to train the network
lr = 0.001        # Learning rate

# read MNIST dataset
mnist = input_data.read_data_sets("MNIST_data", one_hot=True)

# calculate the number of batches per epoch
batch_per_ep = mnist.train.num_examples // batch_size

with tf.Session() as sess:
    sess.run(init)
    for ep in range(epoch_num):  # epochs loop
        for batch_n in range(batch_per_ep):  # batches loop
            batch_img, batch_label = mnist.train.next_batch(batch_size)  # read a batch
            batch_img = batch_img.reshape((-1, 28, 28, 1))               # reshape each sample to an (28, 28) image
            batch_img = resize_batch(batch_img)                          # reshape the images to (32, 32)
            image_arr = []
            for i in xrange(len(batch_img)):
                img = batch_img[i,:,:,0]
                img = s_p(img)
                image_arr.append(img)
            image_arr = np.array(image_arr)
            image_arr = image_arr.reshape(-1,32,32,1)
            #batch_img = image_arr
            _, c = sess.run([train_op, loss], feed_dict={ae_inputs_noise:image_arr,ae_inputs: batch_img})
            print('Epoch: {} - cost= {:.5f}'.format((ep + 1), c))

    # test the trained network
    batch_img, batch_label = mnist.test.next_batch(50)
    batch_img = resize_batch(batch_img)
    image_arr = []
    
    for i in xrange(50):
        img = batch_img[i,:,:,0]
        img = s_p(img)
        image_arr.append(img)
    image_arr = np.array(image_arr)
    image_arr = image_arr.reshape(-1,32,32,1)
    #batch_img = image_arr
            
    recon_img = sess.run([ae_outputs], feed_dict={ae_inputs_noise: image_arr})[0]

    # plot the reconstructed images and their ground truths (inputs)
    plt.figure(1)
    plt.title('Reconstructed Images')
    for i in range(50):
        plt.subplot(5, 10, i+1)
        plt.imshow(recon_img[i, ..., 0], cmap='gray')
    plt.figure(2)
    plt.title('Input Noisy Images with Salt and Pepper Noise')
    for i in range(50):
        plt.subplot(5, 10, i+1)
        plt.imshow(image_arr[i, ..., 0], cmap='gray')
    plt.show()
# Out:
# Extracting MNIST_data/train-images-idx3-ubyte.gz
# Extracting MNIST_data/train-labels-idx1-ubyte.gz
# Extracting MNIST_data/t10k-images-idx3-ubyte.gz
# Extracting MNIST_data/t10k-labels-idx1-ubyte.gz
# Epoch: 1 - cost= 0.10759
# Epoch: 1 - cost= 0.10432
# Epoch: 1 - cost= 0.09145
# Epoch: 1 - cost= 0.10456
# Epoch: 1 - cost= 0.09399
# Epoch: 1 - cost= 0.10294
# Epoch: 1 - cost= 0.09214
# Epoch: 1 - cost= 0.09225
# Epoch: 1 - cost= 0.08686
# Epoch: 1 - cost= 0.08006
# Epoch: 1 - cost= 0.06995
# Epoch: 1 - cost= 0.07494
# Epoch: 1 - cost= 0.07498
# Epoch: 1 - cost= 0.07392
# Epoch: 1 - cost= 0.07664
# Epoch: 1 - cost= 0.07144
# Epoch: 1 - cost= 0.06985
# Epoch: 1 - cost= 0.07153
# Epoch: 1 - cost= 0.06950
# Epoch: 1 - cost= 0.06736
# Epoch: 1 - cost= 0.06618
# Epoch: 1 - cost= 0.06272
# Epoch: 1 - cost= 0.06388
# Epoch: 1 - cost= 0.06702
# Epoch: 1 - cost= 0.06042
# Epoch: 1 - cost= 0.05949
# Epoch: 1 - cost= 0.05825
# Epoch: 1 - cost= 0.06138
# Epoch: 1 - cost= 0.05908
# Epoch: 1 - cost= 0.05936
# Epoch: 1 - cost= 0.05768
# Epoch: 1 - cost= 0.06140
# Epoch: 1 - cost= 0.05921
# Epoch: 1 - cost= 0.05712
# Epoch: 1 - cost= 0.05710
# Epoch: 1 - cost= 0.05707
# Epoch: 1 - cost= 0.05473
# Epoch: 1 - cost= 0.05704
# Epoch: 1 - cost= 0.05394
# Epoch: 1 - cost= 0.05438
# Epoch: 1 - cost= 0.05358
# Epoch: 1 - cost= 0.05391
# Epoch: 1 - cost= 0.05523
# Epoch: 1 - cost= 0.05591
# Epoch: 1 - cost= 0.05353
# Epoch: 1 - cost= 0.05161
# Epoch: 1 - cost= 0.05379
# Epoch: 1 - cost= 0.05069
# Epoch: 1 - cost= 0.05144
# Epoch: 1 - cost= 0.05134
# Epoch: 1 - cost= 0.05242
# Epoch: 1 - cost= 0.05142
# Epoch: 1 - cost= 0.04954
# Epoch: 1 - cost= 0.04959
# Epoch: 1 - cost= 0.05310
# Epoch: 2 - cost= 0.05011
# Epoch: 2 - cost= 0.05037
# Epoch: 2 - cost= 0.04963
# Epoch: 2 - cost= 0.04924
# Epoch: 2 - cost= 0.04925
# Epoch: 2 - cost= 0.04856
# Epoch: 2 - cost= 0.04910
# Epoch: 2 - cost= 0.04818
# Epoch: 2 - cost= 0.04755
# Epoch: 2 - cost= 0.04718
# Epoch: 2 - cost= 0.04682
# Epoch: 2 - cost= 0.04631
# Epoch: 2 - cost= 0.04589
# Epoch: 2 - cost= 0.04556
# Epoch: 2 - cost= 0.04443
# Epoch: 2 - cost= 0.04446
# Epoch: 2 - cost= 0.04471
# Epoch: 2 - cost= 0.04464
# Epoch: 2 - cost= 0.04365
# Epoch: 2 - cost= 0.04266
# Epoch: 2 - cost= 0.04303
# Epoch: 2 - cost= 0.04236
# Epoch: 2 - cost= 0.04200
# Epoch: 2 - cost= 0.04124
# Epoch: 2 - cost= 0.04047
# Epoch: 2 - cost= 0.04019
# Epoch: 2 - cost= 0.04040
# Epoch: 2 - cost= 0.03933
# Epoch: 2 - cost= 0.03860
# Epoch: 2 - cost= 0.03840
# Epoch: 2 - cost= 0.03812
# Epoch: 2 - cost= 0.03728
# Epoch: 2 - cost= 0.03740
# Epoch: 2 - cost= 0.03656
# Epoch: 2 - cost= 0.03623
# Epoch: 2 - cost= 0.03624
# Epoch: 2 - cost= 0.03597
# Epoch: 2 - cost= 0.03491
# Epoch: 2 - cost= 0.03387
# Epoch: 2 - cost= 0.03382
# Epoch: 2 - cost= 0.03343
# Epoch: 2 - cost= 0.03354
# Epoch: 2 - cost= 0.03306
# Epoch: 2 - cost= 0.03278
# Epoch: 2 - cost= 0.03242
# Epoch: 2 - cost= 0.03196
# Epoch: 2 - cost= 0.03193
# Epoch: 2 - cost= 0.03155
# Epoch: 2 - cost= 0.03093
# Epoch: 2 - cost= 0.03086
# Epoch: 2 - cost= 0.03028
# Epoch: 2 - cost= 0.03000
# Epoch: 2 - cost= 0.02928
# Epoch: 2 - cost= 0.02979
# Epoch: 2 - cost= 0.02878
# Epoch: 3 - cost= 0.02946
# Epoch: 3 - cost= 0.02906
# Epoch: 3 - cost= 0.02817
# Epoch: 3 - cost= 0.02792
# Epoch: 3 - cost= 0.02784
# Epoch: 3 - cost= 0.02733
# Epoch: 3 - cost= 0.02747
# Epoch: 3 - cost= 0.02726
# Epoch: 3 - cost= 0.02679
# Epoch: 3 - cost= 0.02682
# Epoch: 3 - cost= 0.02640
# Epoch: 3 - cost= 0.02614
# Epoch: 3 - cost= 0.02615
# Epoch: 3 - cost= 0.02589
# Epoch: 3 - cost= 0.02557
# Epoch: 3 - cost= 0.02495
# Epoch: 3 - cost= 0.02458
# Epoch: 3 - cost= 0.02484
# Epoch: 3 - cost= 0.02413
# Epoch: 3 - cost= 0.02422
# Epoch: 3 - cost= 0.02401
# Epoch: 3 - cost= 0.02397
# Epoch: 3 - cost= 0.02349
# Epoch: 3 - cost= 0.02342
# Epoch: 3 - cost= 0.02330
# Epoch: 3 - cost= 0.02316
# Epoch: 3 - cost= 0.02306
# Epoch: 3 - cost= 0.02292
# Epoch: 3 - cost= 0.02284
# Epoch: 3 - cost= 0.02264
# Epoch: 3 - cost= 0.02191
# Epoch: 3 - cost= 0.02176
# Epoch: 3 - cost= 0.02215
# Epoch: 3 - cost= 0.02200
# Epoch: 3 - cost= 0.02161
# Epoch: 3 - cost= 0.02133
# Epoch: 3 - cost= 0.02095
# Epoch: 3 - cost= 0.02129
# Epoch: 3 - cost= 0.02091
# Epoch: 3 - cost= 0.02075
# Epoch: 3 - cost= 0.02091
# Epoch: 3 - cost= 0.02047
# Epoch: 3 - cost= 0.02032
# Epoch: 3 - cost= 0.02052
# Epoch: 3 - cost= 0.02017
# Epoch: 3 - cost= 0.01995
# Epoch: 3 - cost= 0.02005
# Epoch: 3 - cost= 0.01989
# Epoch: 3 - cost= 0.01984
# Epoch: 3 - cost= 0.01978
# Epoch: 3 - cost= 0.01909
# Epoch: 3 - cost= 0.01949
# Epoch: 3 - cost= 0.01904
# Epoch: 3 - cost= 0.01889
# Epoch: 3 - cost= 0.01892
# Epoch: 4 - cost= 0.01918
# Epoch: 4 - cost= 0.01875
# Epoch: 4 - cost= 0.01877
# Epoch: 4 - cost= 0.01887
# Epoch: 4 - cost= 0.01850
# Epoch: 4 - cost= 0.01841
# Epoch: 4 - cost= 0.01871
# Epoch: 4 - cost= 0.01836
# Epoch: 4 - cost= 0.01765
# Epoch: 4 - cost= 0.01796
# Epoch: 4 - cost= 0.01784
# Epoch: 4 - cost= 0.01795
# Epoch: 4 - cost= 0.01779
# Epoch: 4 - cost= 0.01748
# Epoch: 4 - cost= 0.01748
# Epoch: 4 - cost= 0.01791
# Epoch: 4 - cost= 0.01715
# Epoch: 4 - cost= 0.01712
# Epoch: 4 - cost= 0.01718
# Epoch: 4 - cost= 0.01721
# Epoch: 4 - cost= 0.01709
# Epoch: 4 - cost= 0.01691
# Epoch: 4 - cost= 0.01726
# Epoch: 4 - cost= 0.01685
# Epoch: 4 - cost= 0.01689
# Epoch: 4 - cost= 0.01676
# Epoch: 4 - cost= 0.01646
# Epoch: 4 - cost= 0.01687
# Epoch: 4 - cost= 0.01668
# Epoch: 4 - cost= 0.01670
# Epoch: 4 - cost= 0.01650
# Epoch: 4 - cost= 0.01608
# Epoch: 4 - cost= 0.01635
# Epoch: 4 - cost= 0.01595
# Epoch: 4 - cost= 0.01563
# Epoch: 4 - cost= 0.01603
# Epoch: 4 - cost= 0.01612
# Epoch: 4 - cost= 0.01585
# Epoch: 4 - cost= 0.01598
# Epoch: 4 - cost= 0.01588
# Epoch: 4 - cost= 0.01562
# Epoch: 4 - cost= 0.01567
# Epoch: 4 - cost= 0.01574
# Epoch: 4 - cost= 0.01584
# Epoch: 4 - cost= 0.01579
# Epoch: 4 - cost= 0.01534
# Epoch: 4 - cost= 0.01547
# Epoch: 4 - cost= 0.01506
# Epoch: 4 - cost= 0.01551
# Epoch: 4 - cost= 0.01534
# Epoch: 4 - cost= 0.01527
# Epoch: 4 - cost= 0.01491
# Epoch: 4 - cost= 0.01536
# Epoch: 4 - cost= 0.01509
# Epoch: 4 - cost= 0.01498
# Epoch: 5 - cost= 0.01471
# Epoch: 5 - cost= 0.01482
# Epoch: 5 - cost= 0.01483
# Epoch: 5 - cost= 0.01479
# Epoch: 5 - cost= 0.01488
# Epoch: 5 - cost= 0.01526
# Epoch: 5 - cost= 0.01483
# Epoch: 5 - cost= 0.01472
# Epoch: 5 - cost= 0.01487
# Epoch: 5 - cost= 0.01449
# Epoch: 5 - cost= 0.01458
# Epoch: 5 - cost= 0.01444
# Epoch: 5 - cost= 0.01476
# Epoch: 5 - cost= 0.01406
# Epoch: 5 - cost= 0.01462
# Epoch: 5 - cost= 0.01460
# Epoch: 5 - cost= 0.01453
# Epoch: 5 - cost= 0.01415
# Epoch: 5 - cost= 0.01431
# Epoch: 5 - cost= 0.01422
# Epoch: 5 - cost= 0.01425
# Epoch: 5 - cost= 0.01420
# Epoch: 5 - cost= 0.01398
# Epoch: 5 - cost= 0.01425
# Epoch: 5 - cost= 0.01404
# Epoch: 5 - cost= 0.01395
# Epoch: 5 - cost= 0.01356
# Epoch: 5 - cost= 0.01378
# Epoch: 5 - cost= 0.01409
# Epoch: 5 - cost= 0.01408
# Epoch: 5 - cost= 0.01401
# Epoch: 5 - cost= 0.01345
# Epoch: 5 - cost= 0.01348
# Epoch: 5 - cost= 0.01420
# Epoch: 5 - cost= 0.01386
# Epoch: 5 - cost= 0.01378
# Epoch: 5 - cost= 0.01375
# Epoch: 5 - cost= 0.01316
# Epoch: 5 - cost= 0.01366
# Epoch: 5 - cost= 0.01386
# Epoch: 5 - cost= 0.01338
# Epoch: 5 - cost= 0.01338
# Epoch: 5 - cost= 0.01339
# Epoch: 5 - cost= 0.01333
# Epoch: 5 - cost= 0.01328
# Epoch: 5 - cost= 0.01319
# Epoch: 5 - cost= 0.01316
# Epoch: 5 - cost= 0.01331
# Epoch: 5 - cost= 0.01302
# Epoch: 5 - cost= 0.01315
# Epoch: 5 - cost= 0.01322
# Epoch: 5 - cost= 0.01337
# Epoch: 5 - cost= 0.01339
# Epoch: 5 - cost= 0.01313
# Epoch: 5 - cost= 0.01307
# Epoch: 6 - cost= 0.01282
# Epoch: 6 - cost= 0.01284
# Epoch: 6 - cost= 0.01308
# Epoch: 6 - cost= 0.01309
# Epoch: 6 - cost= 0.01278
# Epoch: 6 - cost= 0.01315
# Epoch: 6 - cost= 0.01292
# Epoch: 6 - cost= 0.01285
# Epoch: 6 - cost= 0.01273
# Epoch: 6 - cost= 0.01313
# Epoch: 6 - cost= 0.01309
# Epoch: 6 - cost= 0.01256
# Epoch: 6 - cost= 0.01272
# Epoch: 6 - cost= 0.01257
# Epoch: 6 - cost= 0.01262
# Epoch: 6 - cost= 0.01267
# Epoch: 6 - cost= 0.01264
# Epoch: 6 - cost= 0.01284
# Epoch: 6 - cost= 0.01296
# Epoch: 6 - cost= 0.01262
# Epoch: 6 - cost= 0.01259
# Epoch: 6 - cost= 0.01243
# Epoch: 6 - cost= 0.01255
# Epoch: 6 - cost= 0.01224
# Epoch: 6 - cost= 0.01256
# Epoch: 6 - cost= 0.01256
# Epoch: 6 - cost= 0.01216
# Epoch: 6 - cost= 0.01217
# Epoch: 6 - cost= 0.01223
# Epoch: 6 - cost= 0.01221
# Epoch: 6 - cost= 0.01225
# Epoch: 6 - cost= 0.01237
# Epoch: 6 - cost= 0.01224
# Epoch: 6 - cost= 0.01236
# Epoch: 6 - cost= 0.01220
# Epoch: 6 - cost= 0.01239
# Epoch: 6 - cost= 0.01216
# Epoch: 6 - cost= 0.01199
# Epoch: 6 - cost= 0.01212
# Epoch: 6 - cost= 0.01214
# Epoch: 6 - cost= 0.01220
# Epoch: 6 - cost= 0.01239
# Epoch: 6 - cost= 0.01203
# Epoch: 6 - cost= 0.01199
# Epoch: 6 - cost= 0.01204
# Epoch: 6 - cost= 0.01212
# Epoch: 6 - cost= 0.01198
# Epoch: 6 - cost= 0.01194
# Epoch: 6 - cost= 0.01195
# Epoch: 6 - cost= 0.01201
# Epoch: 6 - cost= 0.01174
# Epoch: 6 - cost= 0.01179
# Epoch: 6 - cost= 0.01168
# Epoch: 6 - cost= 0.01166
# Epoch: 6 - cost= 0.01204
# Epoch: 7 - cost= 0.01153
# Epoch: 7 - cost= 0.01183
# Epoch: 7 - cost= 0.01158
# Epoch: 7 - cost= 0.01172
# Epoch: 7 - cost= 0.01165
# Epoch: 7 - cost= 0.01178
# Epoch: 7 - cost= 0.01177
# Epoch: 7 - cost= 0.01183
# Epoch: 7 - cost= 0.01178
# Epoch: 7 - cost= 0.01148
# Epoch: 7 - cost= 0.01174
# Epoch: 7 - cost= 0.01197
# Epoch: 7 - cost= 0.01173
# Epoch: 7 - cost= 0.01157
# Epoch: 7 - cost= 0.01137
# Epoch: 7 - cost= 0.01128
# Epoch: 7 - cost= 0.01124
# Epoch: 7 - cost= 0.01130
# Epoch: 7 - cost= 0.01158
# Epoch: 7 - cost= 0.01149
# Epoch: 7 - cost= 0.01130
# Epoch: 7 - cost= 0.01145
# Epoch: 7 - cost= 0.01136
# Epoch: 7 - cost= 0.01104
# Epoch: 7 - cost= 0.01134
# Epoch: 7 - cost= 0.01122
# Epoch: 7 - cost= 0.01141
# Epoch: 7 - cost= 0.01145
# Epoch: 7 - cost= 0.01125
# Epoch: 7 - cost= 0.01134
# Epoch: 7 - cost= 0.01110
# Epoch: 7 - cost= 0.01144
# Epoch: 7 - cost= 0.01146
# Epoch: 7 - cost= 0.01149
# Epoch: 7 - cost= 0.01131
# Epoch: 7 - cost= 0.01113
# Epoch: 7 - cost= 0.01125
# Epoch: 7 - cost= 0.01113
# Epoch: 7 - cost= 0.01142
# Epoch: 7 - cost= 0.01117
# Epoch: 7 - cost= 0.01111
# Epoch: 7 - cost= 0.01123
# Epoch: 7 - cost= 0.01109
# Epoch: 7 - cost= 0.01118
# Epoch: 7 - cost= 0.01106
# Epoch: 7 - cost= 0.01110
# Epoch: 7 - cost= 0.01092
# Epoch: 7 - cost= 0.01061
# Epoch: 7 - cost= 0.01107
# Epoch: 7 - cost= 0.01112
# Epoch: 7 - cost= 0.01086
# Epoch: 7 - cost= 0.01081
# Epoch: 7 - cost= 0.01093
# Epoch: 7 - cost= 0.01084
# Epoch: 7 - cost= 0.01117
# Epoch: 8 - cost= 0.01076
# Epoch: 8 - cost= 0.01089
# Epoch: 8 - cost= 0.01112
# Epoch: 8 - cost= 0.01115
# Epoch: 8 - cost= 0.01065
# Epoch: 8 - cost= 0.01070
# Epoch: 8 - cost= 0.01067
# Epoch: 8 - cost= 0.01088
# Epoch: 8 - cost= 0.01116
# Epoch: 8 - cost= 0.01066
# Epoch: 8 - cost= 0.01060
# Epoch: 8 - cost= 0.01084
# Epoch: 8 - cost= 0.01061
# Epoch: 8 - cost= 0.01043
# Epoch: 8 - cost= 0.01075
# Epoch: 8 - cost= 0.01066
# Epoch: 8 - cost= 0.01084
# Epoch: 8 - cost= 0.01059
# Epoch: 8 - cost= 0.01044
# Epoch: 8 - cost= 0.01063
# Epoch: 8 - cost= 0.01061
# Epoch: 8 - cost= 0.01037
# Epoch: 8 - cost= 0.01033
# Epoch: 8 - cost= 0.01046
# Epoch: 8 - cost= 0.01051
# Epoch: 8 - cost= 0.01065
# Epoch: 8 - cost= 0.01048
# Epoch: 8 - cost= 0.01052
# Epoch: 8 - cost= 0.01029
# Epoch: 8 - cost= 0.01059
# Epoch: 8 - cost= 0.01044
# Epoch: 8 - cost= 0.01069
# Epoch: 8 - cost= 0.01059
# Epoch: 8 - cost= 0.01053
# Epoch: 8 - cost= 0.01045
# Epoch: 8 - cost= 0.01053
# Epoch: 8 - cost= 0.01025
# Epoch: 8 - cost= 0.01036
# Epoch: 8 - cost= 0.01033
# Epoch: 8 - cost= 0.01048
# Epoch: 8 - cost= 0.01053
# Epoch: 8 - cost= 0.01040
# Epoch: 8 - cost= 0.01044
# Epoch: 8 - cost= 0.01038
# Epoch: 8 - cost= 0.01038
# Epoch: 8 - cost= 0.01031
# Epoch: 8 - cost= 0.01025
# Epoch: 8 - cost= 0.01015
# Epoch: 8 - cost= 0.01031
# Epoch: 8 - cost= 0.01020
# Epoch: 8 - cost= 0.00995
# Epoch: 8 - cost= 0.01022
# Epoch: 8 - cost= 0.01045
# Epoch: 8 - cost= 0.01027
# Epoch: 8 - cost= 0.01010
# Epoch: 9 - cost= 0.01020
# Epoch: 9 - cost= 0.01016
# Epoch: 9 - cost= 0.01022
# Epoch: 9 - cost= 0.01009
# Epoch: 9 - cost= 0.01015
# Epoch: 9 - cost= 0.01021
# Epoch: 9 - cost= 0.01011
# Epoch: 9 - cost= 0.00995
# Epoch: 9 - cost= 0.00997
# Epoch: 9 - cost= 0.01007
# Epoch: 9 - cost= 0.01007
# Epoch: 9 - cost= 0.00992
# Epoch: 9 - cost= 0.01016
# Epoch: 9 - cost= 0.01023
# Epoch: 9 - cost= 0.00982
# Epoch: 9 - cost= 0.01019
# Epoch: 9 - cost= 0.01012
# Epoch: 9 - cost= 0.00986
# Epoch: 9 - cost= 0.01003
# Epoch: 9 - cost= 0.01012
# Epoch: 9 - cost= 0.01002
# Epoch: 9 - cost= 0.01022
# Epoch: 9 - cost= 0.01000
# Epoch: 9 - cost= 0.00984
# Epoch: 9 - cost= 0.00969
# Epoch: 9 - cost= 0.00990
# Epoch: 9 - cost= 0.00998
# Epoch: 9 - cost= 0.01005
# Epoch: 9 - cost= 0.00965
# Epoch: 9 - cost= 0.01003
# Epoch: 9 - cost= 0.01001
# Epoch: 9 - cost= 0.00976
# Epoch: 9 - cost= 0.00972
# Epoch: 9 - cost= 0.00952
# Epoch: 9 - cost= 0.00994
# Epoch: 9 - cost= 0.00987
# Epoch: 9 - cost= 0.00952
# Epoch: 9 - cost= 0.00983
# Epoch: 9 - cost= 0.00973
# Epoch: 9 - cost= 0.00958
# Epoch: 9 - cost= 0.00963
# Epoch: 9 - cost= 0.00997
# Epoch: 9 - cost= 0.00999
# Epoch: 9 - cost= 0.00966
# Epoch: 9 - cost= 0.01005
# Epoch: 9 - cost= 0.00971
# Epoch: 9 - cost= 0.00943
# Epoch: 9 - cost= 0.00983
# Epoch: 9 - cost= 0.00968
# Epoch: 9 - cost= 0.00947
# Epoch: 9 - cost= 0.00980
# Epoch: 9 - cost= 0.00954
# Epoch: 9 - cost= 0.00972
# Epoch: 9 - cost= 0.00964
# Epoch: 9 - cost= 0.00961
# Epoch: 10 - cost= 0.00938
# Epoch: 10 - cost= 0.00963
# Epoch: 10 - cost= 0.00955
# Epoch: 10 - cost= 0.00961
# Epoch: 10 - cost= 0.00959
# Epoch: 10 - cost= 0.00949
# Epoch: 10 - cost= 0.00956
# Epoch: 10 - cost= 0.00955
# Epoch: 10 - cost= 0.00934
# Epoch: 10 - cost= 0.00953
# Epoch: 10 - cost= 0.00975
# Epoch: 10 - cost= 0.00939
# Epoch: 10 - cost= 0.00947
# Epoch: 10 - cost= 0.00959
# Epoch: 10 - cost= 0.00943
# Epoch: 10 - cost= 0.00938
# Epoch: 10 - cost= 0.00968
# Epoch: 10 - cost= 0.00918
# Epoch: 10 - cost= 0.00957
# Epoch: 10 - cost= 0.00922
# Epoch: 10 - cost= 0.00948
# Epoch: 10 - cost= 0.00932
# Epoch: 10 - cost= 0.00933
# Epoch: 10 - cost= 0.00958
# Epoch: 10 - cost= 0.00929
# Epoch: 10 - cost= 0.00944
# Epoch: 10 - cost= 0.00941
# Epoch: 10 - cost= 0.00935
# Epoch: 10 - cost= 0.00934
# Epoch: 10 - cost= 0.00917
# Epoch: 10 - cost= 0.00932
# Epoch: 10 - cost= 0.00926
# Epoch: 10 - cost= 0.00957
# Epoch: 10 - cost= 0.00935
# Epoch: 10 - cost= 0.00930
# Epoch: 10 - cost= 0.00930
# Epoch: 10 - cost= 0.00928
# Epoch: 10 - cost= 0.00931
# Epoch: 10 - cost= 0.00935
# Epoch: 10 - cost= 0.00923
# Epoch: 10 - cost= 0.00950
# Epoch: 10 - cost= 0.00931
# Epoch: 10 - cost= 0.00910
# Epoch: 10 - cost= 0.00952
# Epoch: 10 - cost= 0.00923
# Epoch: 10 - cost= 0.00913
# Epoch: 10 - cost= 0.00939
# Epoch: 10 - cost= 0.00926
# Epoch: 10 - cost= 0.00940
# Epoch: 10 - cost= 0.00926
# Epoch: 10 - cost= 0.00919
# Epoch: 10 - cost= 0.00906
# Epoch: 10 - cost= 0.00907
# Epoch: 10 - cost= 0.00905
# Epoch: 10 - cost= 0.00896
